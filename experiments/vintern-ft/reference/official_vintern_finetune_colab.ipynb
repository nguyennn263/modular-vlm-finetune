# %% [markdown]
# # **Fine-tuning Vintern-1B-v3_5 on 5CD/Viet-Receipt-VQA**
#
# In this notebook, we will fine-tune Vintern-1B by 5CD/Viet-Receipt-VQA an Vietnamese dataset, a new vision language model capable of various tasks, on document question answering for Vietnamese.
#
# Reference: https://internvl.readthedocs.io/en/latest/internvl2.0/finetune.html
#
# Check it more about us: [Fifth Civil Defender - 5CD - AI](https://huggingface.co/5CD-AI)
#
# Let's start by installing the dependencies and loading the dataset.

# %%
# !pip install -q timm einops peft wandb deepspeed accelerate bitsandbytes decord tensorboardX gdown
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 28.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 13.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 75.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 79.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 66.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 95.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.8/422.8 kB 32.8 MB/s eta 0:00:00
#   Building wheel for deepspeed (setup.py) ... done

# %%
# !pip install -U datasets
# !pip install transformers==4.47.0
# !pip install flash_attn==2.7.2.post1
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (2.14.4)
# Collecting datasets
#   Downloading datasets-3.6.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.15)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.33.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.11.15)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.6.15)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.6.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 20.1 MB/s eta 0:00:00
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 18.3 MB/s eta 0:00:00
# Installing collected packages: fsspec, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.14.4
#     Uninstalling datasets-2.14.4:
#       Successfully uninstalled datasets-2.14.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# Successfully installed datasets-3.6.0 fsspec-2025.3.0
# Collecting transformers==4.47.0
#   Downloading transformers-4.47.0-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.47.0) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.47.0) (0.33.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.47.0) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.47.0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.47.0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.47.0) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.47.0) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers==4.47.0) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.47.0) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.47.0) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers==4.47.0) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers==4.47.0) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers==4.47.0) (1.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.47.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.47.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.47.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.47.0) (2025.6.15)
# Downloading transformers-4.47.0-py3-none-any.whl (10.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 78.3 MB/s eta 0:00:00
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.52.4
#     Uninstalling transformers-4.52.4:
#       Successfully uninstalled transformers-4.52.4
# Successfully installed transformers-4.47.0
# Collecting flash_attn==2.7.2.post1
#   Downloading flash_attn-2.7.2.post1.tar.gz (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 84.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from flash_attn==2.7.2.post1) (2.6.0+cu124)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from flash_attn==2.7.2.post1) (0.8.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->flash_attn==2.7.2.post1) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->flash_attn==2.7.2.post1) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->flash_attn==2.7.2.post1) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->flash_attn==2.7.2.post1) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->flash_attn==2.7.2.post1) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->flash_attn==2.7.2.post1) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->flash_attn==2.7.2.post1) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->flash_attn==2.7.2.post1) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->flash_attn==2.7.2.post1) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->flash_attn==2.7.2.post1) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->flash_attn==2.7.2.post1) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->flash_attn==2.7.2.post1) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->flash_attn==2.7.2.post1) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->flash_attn==2.7.2.post1) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->flash_attn==2.7.2.post1) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->flash_attn==2.7.2.post1) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->flash_attn==2.7.2.post1) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->flash_attn==2.7.2.post1) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->flash_attn==2.7.2.post1) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->flash_attn==2.7.2.post1) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->flash_attn==2.7.2.post1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->flash_attn==2.7.2.post1) (3.0.2)
# Building wheels for collected packages: flash_attn
#   Building wheel for flash_attn (setup.py) ... done
#   Created wheel for flash_attn: filename=flash_attn-2.7.2.post1-cp311-cp311-linux_x86_64.whl size=190180789 sha256=8596401f69dea28c0c9f2ea8ee5b636876eb2ea511c34849b8063c46ee37a4fd
#   Stored in directory: /root/.cache/pip/wheels/6a/8b/7d/0ac2b18cb28f4104a1852da090dcf9ea8239ce45fc82bcc4d1
# Successfully built flash_attn
# Installing collected packages: flash_attn
# Successfully installed flash_attn-2.7.2.post1

# %%
# !git clone https://github.com/5CD-AI/Vintern.git
# %cd Vintern
# Out:
# Cloning into 'Vintern'...
# remote: Enumerating objects: 2361, done.
# remote: Counting objects: 100% (835/835), done.
# remote: Compressing objects: 100% (213/213), done.
# remote: Total 2361 (delta 672), reused 622 (delta 622), pack-reused 1526 (from 1)
# Receiving objects: 100% (2361/2361), 36.42 MiB | 13.41 MiB/s, done.
# Resolving deltas: 100% (1389/1389), done.
# /content/Vintern

# %% [markdown]
# # **Load dataset**

# %%
from datasets import load_dataset, Image
vi_receipt_dataset = load_dataset("5CD-AI/Viet-Receipt-VQA")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# train-00000-of-00003.parquet:   0%|          | 0.00/154M [00:00<?, ?B/s]
# train-00001-of-00003.parquet:   0%|          | 0.00/154M [00:00<?, ?B/s]
# train-00002-of-00003.parquet:   0%|          | 0.00/152M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/2034 [00:00<?, ? examples/s]

# %%
vi_receipt_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'image', 'description', 'extractions', 'conversations'],
#         num_rows: 2034
#     })
# })

# %%
vi_receipt_dataset['train'][0]
# Out:
# {'id': 443,
#  'image': <PIL.Image.Image image mode=RGB size=768x1024>,
#  'description': 'Hóa đơn bán hàng của Vincommerce, ngày 14/08/2020, 21:37, mã hóa đơn H:00073344, NVBH:09021213,  gồm 1 mặt hàng là Kem hướng sữa  riêng Vinamilk hộp 450ml với đơn giá 43.800, tổng tiền phải trả 43.800, tiền khách trả 50.000, tiền trả lại 6.200.',
#  'extractions': "{'Tên cửa hàng': 'Vincommerce', 'Địa chỉ': 'DA khu DCLB cóc 8, P. Cẩm Sơn, TP. Cẩm Phả, T. Quảng Ninh', 'Số điện thoại': '024.71066866-44561', 'Ngày bán': '14/08/2020', 'Giờ bán': '21:37', 'Số quầy': '001', 'Mã hóa đơn': 'H:00073344', 'NVBH': '09021213', 'Mặt hàng': 'Kem hướng sữa  riêng Vinamilk hộp 450ml', 'Đơn giá': '43.800', 'Số lượng': '1', 'Tổng tiền': '43.800', 'Tổng tiền à giảm': '0', 'Tiền khách trả': '43.800', 'Tiền mặt': '50.000', 'Tiền trả lại': '6.200'}",
#  'conversations': [{'role': 'user',
#    'content': 'Hóa đơn được xuất tại cửa hàng nào?'},
#   {'role': 'assistant',
#    'content': 'Hóa đơn được xuất tại cửa hàng Vincommerce.'},
#   {'role': 'user', 'content': 'Địa chỉ của cửa hàng là gì?'},
#   {'role': 'assistant',
#    'content': 'Địa chỉ của cửa hàng là DA khu DCLB cóc 8, P. Cẩm Sơn, TP. Cẩm Phả, T. Quảng Ninh.'},
#   {'role': 'user', 'content': 'Hóa đơn được xuất vào ngày nào?'},
#   {'role': 'assistant', 'content': 'Hóa đơn được xuất vào ngày 14/08/2020.'},
#   {'role': 'user', 'content': 'Tổng số tiền phải thanh toán là bao nhiêu?'},
#   {'role': 'assistant', 'content': 'Tổng số tiền phải thanh toán là 43.800.'},
#   {'role': 'user', 'content': 'Khách hàng đã thanh toán bằng cách nào?'},
#   {'role': 'assistant', 'content': 'Khách hàng đã thanh toán bằng tiền mặt.'}]}

# %% [markdown]
# # **Prepare model**

# %% [markdown]
# ## Download model

# %% [markdown]
# Before starting the second fine-tuning, download the pre-trained model is provided.

# %%
# !mkdir -p pretrained
# %cd pretrained/
# Download 5CD-AI/Vintern-1B-v2 ---- Vision Part:InternViT‑300M‑448px + Language Part: Qwen2‑0.5B‑Instruct
# !huggingface-cli download --resume-download --local-dir-use-symlinks False 5CD-AI/Vintern-1B-v2 --local-dir Vintern-1B-v2
# !huggingface-cli download --resume-download --local-dir-use-symlinks False 5CD-AI/Vintern-1B-v3_5 --local-dir Vintern-1B-v3_5
# Out:
# /content/Vintern/pretrained
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/commands/download.py:139: FutureWarning: Ignoring --local-dir-use-symlinks. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Fetching 15 files:   0% 0/15 [00:00<?, ?it/s]Downloading 'config.json' to 'Vintern-1B-v3_5/.cache/huggingface/download/8_PA_wEVGiVa2goH2H4KQOQpvVY=.2668519f652eddcc2abbb56a52518d38c4f88887.incomplete'
# Downloading 'README.md' to 'Vintern-1B-v3_5/.cache/huggingface/download/Xn7B-BWUGOee2Y6hCZtEhtFu4BE=.6db3e18fbb4f1056a8c34d0d5fef211588d49264.incomplete'
# Downloading 'added_tokens.json' to 'Vintern-1B-v3_5/.cache/huggingface/download/SeqzFlf9ZNZ3or_wZAOIdsM3Yxw=.dd972e4080e791eab591742c1168ee7fd6279146.incomplete'
#
# config.json: 5.30kB [00:00, 17.4MB/s]
# Download complete. Moving file to Vintern-1B-v3_5/config.json
# Downloading '.gitattributes' to 'Vintern-1B-v3_5/.cache/huggingface/download/wPaCkH-WbT7GsmxMKKrNZTV4nSM=.a6344aac8c09253b3b630fb776ae94478aa0275b.incomplete'
# Downloading 'conversation.py' to 'Vintern-1B-v3_5/.cache/huggingface/download/DEizyvx9GSqAZTOB7ZJABNlK3H0=.76fcea7f331de42b6aed7e39fdf80728f9784b7f.incomplete'
# Downloading 'configuration_intern_vit.py' to 'Vintern-1B-v3_5/.cache/huggingface/download/_MrF22XZuffGbJP8rB83lHzm0u4=.7e630c456eb9cf350e55bf850c3ff72f445a7e17.incomplete'
#
# .gitattributes: 1.52kB [00:00, 4.93MB/s]
# Download complete. Moving file to Vintern-1B-v3_5/.gitattributes
# Fetching 15 files:   7% 1/15 [00:00<00:10,  1.40it/s]
# README.md: 10.3kB [00:00, 25.9MB/s]
# Download complete. Moving file to Vintern-1B-v3_5/README.md
#
# configuration_intern_vit.py: 5.55kB [00:00, 21.6MB/s]
# Download complete. Moving file to Vintern-1B-v3_5/configuration_intern_vit.py
#
# added_tokens.json: 100% 790/790 [00:00<00:00, 5.32MB/s]
# Download complete. Moving file to Vintern-1B-v3_5/added_tokens.json
#
# conversation.py: 16.4kB [00:00, 45.8MB/s]
# Download complete. Moving file to Vintern-1B-v3_5/conversation.py
# Downloading 'generation_config.json' to 'Vintern-1B-v3_5/.cache/huggingface/download/3EVKVggOldJcKSsGjSdoUCN1AyQ=.cd9a20c20b3f0f173cff8cae0392521c06342afa.incomplete'
# Downloading 'configuration_internvl_chat.py' to 'Vintern-1B-v3_5/.cache/huggingface/download/DsLREbI1OaCt0aQRMkT6-8j8O0Q=.799209432caf749e77de4c889ec03fe6a32fcdf9.incomplete'
# Downloading 'merges.txt' to 'Vintern-1B-v3_5/.cache/huggingface/download/PtHk0z_I45atnj23IIRhTExwT3w=.8488ce08857fb9abc0dd05fd9f399d6d0234686f.incomplete'
# Downloading 'model.safetensors' to 'Vintern-1B-v3_5/.cache/huggingface/download/xGOKKLRSlIhH692hSVvI1-gpoa8=.296a16a6bf28e6d3f0fb9298deba70b3cfa1d7519f4aa326e2f862bf2e63be05.incomplete'
# Downloading 'tokenizer_config.json' to 'Vintern-1B-v3_5/.cache/huggingface/download/vzaExXFZNBay89bvlQv-ZcI6BTg=.096d822badcaf73b141f570f46642ce486d39dd5.incomplete'
#
# generation_config.json: 100% 129/129 [00:00<00:00, 1.06MB/s]
# Download complete. Moving file to Vintern-1B-v3_5/generation_config.json
#
# model.safetensors:   0% 0.00/3.75G [00:00<?, ?B/s]
#
# configuration_internvl_chat.py: 3.88kB [00:00, 15.2MB/s]
# Download complete. Moving file to Vintern-1B-v3_5/configuration_internvl_chat.py
# Fetching 15 files:  40% 6/15 [00:01<00:01,  6.47it/s]
# model.safetensors:   1% 21.0M/3.75G [00:00<00:25, 146MB/s]Downloading 'modeling_internvl_chat.py' to 'Vintern-1B-v3_5/.cache/huggingface/download/0iPZ4DgR3ByT0g6iDwA8qs1ngbc=.41f48cd5cb907e025725fc42ac819cf3f03c01b5.incomplete'
# Downloading 'special_tokens_map.json' to 'Vintern-1B-v3_5/.cache/huggingface/download/ahkChHUJFxEmOdq5GDFEmerRzCY=.74ea6ef5bd52e11d45791fbab7cca3dc984942fa.incomplete'
#
#
# tokenizer_config.json: 9.02kB [00:00, 31.7MB/s]
# Download complete. Moving file to Vintern-1B-v3_5/tokenizer_config.json
#
#
# merges.txt: 0.00B [00:00, ?B/s]
# model.safetensors:   1% 52.4M/3.75G [00:00<00:17, 210MB/s]
#
# merges.txt: 671kB [00:00, 6.65MB/s]
# model.safetensors:   2% 83.9M/3.75G [00:00<00:17, 206MB/s]
#
#
# modeling_internvl_chat.py: 15.6kB [00:00, 39.4MB/s]
# Download complete. Moving file to Vintern-1B-v3_5/modeling_internvl_chat.py
# merges.txt: 1.67MB [00:00, 8.70MB/s]
# Download complete. Moving file to Vintern-1B-v3_5/merges.txt
# Fetching 15 files:  60% 9/15 [00:01<00:00,  7.18it/s]Downloading 'vocab.json' to 'Vintern-1B-v3_5/.cache/huggingface/download/j3m-Hy6QvBddw8RXA1uSWl1AJ0c=.6bce3a0a3866c4791a74d83d78f6824c3af64ec3.incomplete'
#
# model.safetensors:   3% 105M/3.75G [00:00<00:18, 194MB/s]
#
# special_tokens_map.json: 100% 744/744 [00:00<00:00, 5.07MB/s]
# Download complete. Moving file to Vintern-1B-v3_5/special_tokens_map.json
# Downloading 'modeling_intern_vit.py' to 'Vintern-1B-v3_5/.cache/huggingface/download/RTKxUQNMcYzd9NdDH76_hzPG1AI=.1c5c043a4b860720b3b6e55107e8e6ecf0c573de.incomplete'
#
# model.safetensors:   4% 136M/3.75G [00:00<00:16, 216MB/s]
#
# vocab.json: 0.00B [00:00, ?B/s]
#
# vocab.json: 1.43MB [00:00, 14.3MB/s]
# model.safetensors:   4% 168M/3.75G [00:00<00:19, 187MB/s]
#
#
# modeling_intern_vit.py: 18.1kB [00:00, 34.6MB/s]
# Download complete. Moving file to Vintern-1B-v3_5/modeling_intern_vit.py
#
#
# vocab.json: 3.38MB [00:00, 14.7MB/s]
# Download complete. Moving file to Vintern-1B-v3_5/vocab.json
#
# model.safetensors:   5% 189M/3.75G [00:00<00:19, 181MB/s]
# model.safetensors:   6% 220M/3.75G [00:01<00:18, 196MB/s]
# model.safetensors:   7% 252M/3.75G [00:01<00:16, 215MB/s]
# model.safetensors:   8% 283M/3.75G [00:01<00:15, 230MB/s]
# model.safetensors:   8% 315M/3.75G [00:01<00:16, 215MB/s]
# model.safetensors:   9% 346M/3.75G [00:01<00:16, 203MB/s]
# model.safetensors:  10% 377M/3.75G [00:01<00:15, 224MB/s]
# model.safetensors:  11% 409M/3.75G [00:01<00:15, 217MB/s]
# model.safetensors:  12% 440M/3.75G [00:02<00:14, 234MB/s]
# model.safetensors:  13% 472M/3.75G [00:02<00:15, 211MB/s]
# model.safetensors:  13% 503M/3.75G [00:02<00:16, 197MB/s]
# model.safetensors:  14% 535M/3.75G [00:02<00:15, 203MB/s]
# model.safetensors:  15% 566M/3.75G [00:02<00:14, 219MB/s]
# model.safetensors:  16% 598M/3.75G [00:02<00:14, 217MB/s]
# model.safetensors:  17% 629M/3.75G [00:02<00:13, 236MB/s]
# model.safetensors:  18% 661M/3.75G [00:03<00:12, 245MB/s]
# model.safetensors:  18% 692M/3.75G [00:03<00:12, 254MB/s]
# model.safetensors:  19% 724M/3.75G [00:03<00:12, 248MB/s]
# model.safetensors:  20% 765M/3.75G [00:03<00:11, 260MB/s]
# model.safetensors:  21% 797M/3.75G [00:03<00:11, 250MB/s]
# model.safetensors:  22% 828M/3.75G [00:03<00:11, 258MB/s]
# model.safetensors:  23% 870M/3.75G [00:03<00:09, 290MB/s]
# model.safetensors:  24% 902M/3.75G [00:03<00:10, 262MB/s]
# model.safetensors:  25% 933M/3.75G [00:04<00:10, 261MB/s]
# model.safetensors:  26% 965M/3.75G [00:04<00:10, 257MB/s]
# model.safetensors:  27% 996M/3.75G [00:04<00:10, 268MB/s]
# model.safetensors:  27% 1.03G/3.75G [00:04<00:10, 260MB/s]
# model.safetensors:  28% 1.07G/3.75G [00:04<00:09, 281MB/s]
# model.safetensors:  30% 1.11G/3.75G [00:04<00:09, 279MB/s]
# model.safetensors:  30% 1.14G/3.75G [00:04<00:10, 257MB/s]
# model.safetensors:  31% 1.17G/3.75G [00:05<00:09, 270MB/s]
# model.safetensors:  32% 1.21G/3.75G [00:05<00:10, 254MB/s]
# model.safetensors:  33% 1.24G/3.75G [00:05<00:09, 256MB/s]
# model.safetensors:  34% 1.27G/3.75G [00:05<00:09, 268MB/s]
# model.safetensors:  35% 1.30G/3.75G [00:05<00:08, 274MB/s]
# model.safetensors:  36% 1.34G/3.75G [00:05<00:08, 284MB/s]
# model.safetensors:  37% 1.37G/3.75G [00:05<00:08, 279MB/s]
# model.safetensors:  37% 1.41G/3.75G [00:05<00:09, 257MB/s]
# model.safetensors:  38% 1.44G/3.75G [00:05<00:08, 266MB/s]
# model.safetensors:  39% 1.47G/3.75G [00:06<00:08, 275MB/s]
# model.safetensors:  40% 1.50G/3.75G [00:06<00:08, 274MB/s]
# model.safetensors:  41% 1.53G/3.75G [00:06<00:08, 257MB/s]
# model.safetensors:  42% 1.56G/3.75G [00:06<00:08, 261MB/s]
# model.safetensors:  42% 1.59G/3.75G [00:06<00:08, 256MB/s]
# model.safetensors:  43% 1.63G/3.75G [00:06<00:08, 264MB/s]
# model.safetensors:  44% 1.67G/3.75G [00:06<00:07, 270MB/s]
# model.safetensors:  45% 1.70G/3.75G [00:07<00:10, 193MB/s]
# model.safetensors:  46% 1.74G/3.75G [00:07<00:09, 223MB/s]
# model.safetensors:  47% 1.78G/3.75G [00:07<00:07, 250MB/s]
# model.safetensors:  48% 1.81G/3.75G [00:07<00:07, 261MB/s]
# model.safetensors:  49% 1.85G/3.75G [00:07<00:07, 263MB/s]
# model.safetensors:  50% 1.88G/3.75G [00:07<00:06, 275MB/s]
# model.safetensors:  51% 1.91G/3.75G [00:07<00:06, 270MB/s]
# model.safetensors:  52% 1.94G/3.75G [00:08<00:07, 240MB/s]
# model.safetensors:  53% 1.97G/3.75G [00:08<00:06, 257MB/s]
# model.safetensors:  53% 2.00G/3.75G [00:08<00:06, 266MB/s]
# model.safetensors:  54% 2.03G/3.75G [00:08<00:06, 277MB/s]
# model.safetensors:  55% 2.07G/3.75G [00:08<00:05, 286MB/s]
# model.safetensors:  56% 2.11G/3.75G [00:08<00:05, 308MB/s]
# model.safetensors:  57% 2.14G/3.75G [00:08<00:05, 275MB/s]
# model.safetensors:  58% 2.17G/3.75G [00:08<00:07, 216MB/s]
# model.safetensors:  59% 2.20G/3.75G [00:09<00:07, 220MB/s]
# model.safetensors:  60% 2.23G/3.75G [00:09<00:07, 206MB/s]
# model.safetensors:  60% 2.26G/3.75G [00:09<00:07, 207MB/s]
# model.safetensors:  61% 2.30G/3.75G [00:09<00:07, 190MB/s]
# model.safetensors:  62% 2.32G/3.75G [00:09<00:08, 177MB/s]
# model.safetensors:  63% 2.35G/3.75G [00:09<00:07, 190MB/s]
# model.safetensors:  63% 2.37G/3.75G [00:09<00:07, 184MB/s]
# model.safetensors:  64% 2.39G/3.75G [00:10<00:10, 133MB/s]
# model.safetensors:  64% 2.41G/3.75G [00:10<00:09, 146MB/s]
# model.safetensors:  65% 2.43G/3.75G [00:10<00:10, 129MB/s]
# model.safetensors:  65% 2.45G/3.75G [00:10<00:11, 118MB/s]
# model.safetensors:  66% 2.47G/3.75G [00:10<00:10, 124MB/s]
# model.safetensors:  66% 2.50G/3.75G [00:11<00:09, 138MB/s]
# model.safetensors:  67% 2.52G/3.75G [00:11<00:08, 144MB/s]
# model.safetensors:  68% 2.54G/3.75G [00:13<00:53, 22.7MB/s]
# model.safetensors:  68% 2.56G/3.75G [00:14<00:38, 30.8MB/s]
# model.safetensors:  69% 2.58G/3.75G [00:14<00:28, 41.1MB/s]
# model.safetensors:  70% 2.63G/3.75G [00:14<00:14, 77.8MB/s]
# model.safetensors:  71% 2.67G/3.75G [00:14<00:09, 109MB/s]
# model.safetensors:  72% 2.72G/3.75G [00:14<00:07, 143MB/s]
# model.safetensors:  73% 2.75G/3.75G [00:14<00:06, 164MB/s]
# model.safetensors:  74% 2.78G/3.75G [00:14<00:05, 167MB/s]
# model.safetensors:  75% 2.81G/3.75G [00:20<00:49, 19.2MB/s]
# model.safetensors:  76% 2.86G/3.75G [00:20<00:28, 31.3MB/s]
# model.safetensors:  77% 2.89G/3.75G [00:20<00:22, 38.6MB/s]
# model.safetensors:  79% 2.95G/3.75G [00:20<00:13, 59.1MB/s]
# model.safetensors:  79% 2.98G/3.75G [00:20<00:10, 73.6MB/s]
# model.safetensors:  81% 3.03G/3.75G [00:20<00:06, 106MB/s]
# model.safetensors:  82% 3.07G/3.75G [00:21<00:05, 128MB/s]
# model.safetensors:  83% 3.10G/3.75G [00:21<00:05, 124MB/s]
# model.safetensors:  84% 3.14G/3.75G [00:21<00:05, 113MB/s]
# model.safetensors:  84% 3.16G/3.75G [00:21<00:06, 98.4MB/s]
# model.safetensors:  85% 3.18G/3.75G [00:26<00:30, 18.7MB/s]
# model.safetensors:  85% 3.20G/3.75G [00:26<00:23, 23.7MB/s]
# model.safetensors:  86% 3.23G/3.75G [00:26<00:15, 34.1MB/s]
# model.safetensors:  87% 3.27G/3.75G [00:26<00:09, 52.9MB/s]
# model.safetensors:  88% 3.30G/3.75G [00:26<00:06, 70.0MB/s]
# model.safetensors:  89% 3.33G/3.75G [00:26<00:04, 90.4MB/s]
# model.safetensors:  90% 3.37G/3.75G [00:27<00:03, 114MB/s]
# model.safetensors:  91% 3.42G/3.75G [00:27<00:02, 164MB/s]
# model.safetensors:  92% 3.46G/3.75G [00:27<00:01, 185MB/s]
# model.safetensors:  93% 3.49G/3.75G [00:27<00:01, 151MB/s]
# model.safetensors:  94% 3.52G/3.75G [00:27<00:01, 173MB/s]
# model.safetensors:  95% 3.57G/3.75G [00:27<00:00, 206MB/s]
# model.safetensors:  96% 3.61G/3.75G [00:27<00:00, 245MB/s]
# model.safetensors:  98% 3.66G/3.75G [00:28<00:00, 273MB/s]
# model.safetensors:  99% 3.70G/3.75G [00:28<00:00, 198MB/s]
# model.safetensors: 100% 3.75G/3.75G [00:28<00:00, 131MB/s]
# Download complete. Moving file to Vintern-1B-v3_5/model.safetensors
# Fetching 15 files: 100% 15/15 [00:29<00:00,  1.98s/it]
# /content/Vintern/pretrained/Vintern-1B-v3_5

# %% [markdown]
# ## Test single image

# %% [markdown]
# Let's do inference with our dataset first to see how the model performs already with our dataset before fine-tuning. After testing you should clear the gpu (restart session) for next steps.

# %%
#### Do not use flash attention if your device not support

# import json
# with open('pretrained/InternVL2-1B/config.json', 'r') as f:
#     config = json.load(f)
# config["vision_config"]["use_flash_attn"] = False
# with open('pretrained/InternVL2-1B/config.json', 'w') as f:
#     json.dump(config, f)

# %%
import os
import numpy as np
import torch
import torchvision.transforms as T
from PIL import Image
from torchvision.transforms.functional import InterpolationMode
from transformers import AutoModel, AutoTokenizer
import matplotlib.pyplot as plt

IMAGENET_MEAN = (0.485, 0.456, 0.406)
IMAGENET_STD = (0.229, 0.224, 0.225)

def build_transform(input_size):
    MEAN, STD = IMAGENET_MEAN, IMAGENET_STD
    transform = T.Compose([
        T.Lambda(lambda img: img.convert('RGB') if img.mode != 'RGB' else img),
        T.Resize((input_size, input_size), interpolation=InterpolationMode.BICUBIC),
        T.ToTensor(),
        T.Normalize(mean=MEAN, std=STD)
    ])
    return transform

def find_closest_aspect_ratio(aspect_ratio, target_ratios, width, height, image_size):
    best_ratio_diff = float('inf')
    best_ratio = (1, 1)
    area = width * height
    for ratio in target_ratios:
        target_aspect_ratio = ratio[0] / ratio[1]
        ratio_diff = abs(aspect_ratio - target_aspect_ratio)
        if ratio_diff < best_ratio_diff:
            best_ratio_diff = ratio_diff
            best_ratio = ratio
        elif ratio_diff == best_ratio_diff:
            if area > 0.5 * image_size * image_size * ratio[0] * ratio[1]:
                best_ratio = ratio
    return best_ratio

def dynamic_preprocess(image, min_num=1, max_num=12, image_size=448, use_thumbnail=False):
    orig_width, orig_height = image.size
    aspect_ratio = orig_width / orig_height

    # calculate the existing image aspect ratio
    target_ratios = set(
        (i, j) for n in range(min_num, max_num + 1) for i in range(1, n + 1) for j in range(1, n + 1) if
        i * j <= max_num and i * j >= min_num)
    target_ratios = sorted(target_ratios, key=lambda x: x[0] * x[1])

    # find the closest aspect ratio to the target
    target_aspect_ratio = find_closest_aspect_ratio(
        aspect_ratio, target_ratios, orig_width, orig_height, image_size)

    # calculate the target width and height
    target_width = image_size * target_aspect_ratio[0]
    target_height = image_size * target_aspect_ratio[1]
    blocks = target_aspect_ratio[0] * target_aspect_ratio[1]

    # resize the image
    resized_img = image.resize((target_width, target_height))
    processed_images = []
    for i in range(blocks):
        box = (
            (i % (target_width // image_size)) * image_size,
            (i // (target_width // image_size)) * image_size,
            ((i % (target_width // image_size)) + 1) * image_size,
            ((i // (target_width // image_size)) + 1) * image_size
        )
        # split the image
        split_img = resized_img.crop(box)
        processed_images.append(split_img)
    assert len(processed_images) == blocks
    if use_thumbnail and len(processed_images) != 1:
        thumbnail_img = image.resize((image_size, image_size))
        processed_images.append(thumbnail_img)
    return processed_images

def load_image(image_file, input_size=448, max_num=12):
    #check image_file is a path or image
    if isinstance(image_file, str):
        image = Image.open(image_file).convert('RGB')
    else:
        image = image_file
    transform = build_transform(input_size=input_size)
    images = dynamic_preprocess(image, image_size=input_size, use_thumbnail=True, max_num=max_num)
    pixel_values = [transform(image) for image in images]
    pixel_values = torch.stack(pixel_values)
    return pixel_values
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]

# %%
## load pretrained model
model_name = "/content/Vintern/pretrained/Vintern-1B-v3_5"
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True, use_fast=False)
model = AutoModel.from_pretrained(
    model_name,
    torch_dtype=torch.bfloat16,
    low_cpu_mem_usage=True,
    trust_remote_code=True,
    use_flash_attn=False,
).eval().cuda()
# Out:
# configuration_internvl_chat.py: 0.00B [00:00, ?B/s]
# configuration_intern_vit.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/5CD-AI/Vintern-1B-v3_5:
# - configuration_intern_vit.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/5CD-AI/Vintern-1B-v3_5:
# - configuration_internvl_chat.py
# - configuration_intern_vit.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_internvl_chat.py: 0.00B [00:00, ?B/s]
# conversation.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/5CD-AI/Vintern-1B-v3_5:
# - conversation.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_intern_vit.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/5CD-AI/Vintern-1B-v3_5:
# - modeling_intern_vit.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/5CD-AI/Vintern-1B-v3_5:
# - modeling_internvl_chat.py
# - conversation.py
# - modeling_intern_vit.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)

# %%
### Test samples
for i in range(3):
    image = vi_receipt_dataset['train'][i]['image']

    plt.figure(figsize=(5,5))
    plt.imshow(image)
    plt.show()

    pixel_values = load_image(image, max_num=12).to(torch.bfloat16).cuda()
    generation_config = dict(max_new_tokens= 1024, do_sample=False, num_beams = 3, repetition_penalty=2.0)

    question = '\nTrích xuất thông tin hoá đơn trong ảnh.'

    response = model.chat(tokenizer, pixel_values, question, generation_config)
    print(f'User: {question}\nAssistant: {response}')
    print("="*30)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (3400 > 1700). Running this sequence through the model will result in indexing errors
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# User:
# Trích xuất thông tin hoá đơn trong ảnh.
# Assistant: **Thông tin hoá đơn:**
#
# * **Ngày bán:** 14/08/2020
# * **Giờ bán:** 21:37
# * **Số hoá đơn:** H:00073344
# * **Số NVBH:** 09021213
# * **Mặt hàng:** Kem hương sầu riêng Vinamilk hộp 450ml
# * **Đơn giá:** 43.800 VNĐ
# * **Số lượng:** 1
# * **Tổng tiền:** 43.800 VNĐ
# * **Tiền khách trả:** 43.800 VNĐ
# * **Tiền giảm:** 0 VNĐ
# * **Tiền trả lại:** 6.200 VNĐ
# ==============================
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# User:
# Trích xuất thông tin hoá đơn trong ảnh.
# Assistant: Hóa đơn số 0309129418-115, ngày 20/09/2019, nhân viên Đoàn Quang Trung, số hóa đơn 08459, giá trị 14.000.000 VNĐ, tổng số lượng hàng 1, VAT 10% 14.000.000 VNĐ, tiền mặt 14.000.000 VNĐ, bảo hiểm thuế GTGT 10% 14.000.000 VNĐ, thông tin khách hàng than thiết: EDERACMNJANMY 13:24 25051 25051.
# ==============================
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# User:
# Trích xuất thông tin hoá đơn trong ảnh.
# Assistant: **Thông tin hoá đơn:**
#
# * **Ngày:** 20/09/2019
# * **Giờ:** 10:23:36
# * **Quầy:** 02
# * **Nhân viên:** Đoàn Quang Trung
# * **Số hóa đơn:** 08422
# * **Mã số thuế:** 0309129410-115
# * **Công ty:** Saigon Co.op Food HN THE K-PARK
# * **Địa chỉ:** Tầng 1, SH42 - Toà K3, Công trình chung cư kết hợp dịch vụ trên ô đất H-CT2 thuộc Khu nhà ở Hi Brand tại Khu đô thị mới Văn Phủ, P. Phú La, Q. Hà Đông, Tp Hà Nội.
# * **Email:** cfthekpark@coopfood.vn
# * **Website:** www.saigonco-op.com.vn
# * **Tổng số tiền thanh toán:** 38,774.00 VNĐ
# * **Tổng số lượng hàng:** 4
# * **Phương thức thanh toán:** Tiền mặt
# * **Tiền thừa:** -61,226.00 VNĐ
# * **Thuế GTGT 5%:** 1,370.19 VNĐ
# * **Thuế GTGT 10%:** 909.09 VNĐ
# * **Mã hóa đơn:** E0ERACMLYANMY 10:24 25051
# ==============================

# %%
torch.cuda.empty_cache()

# %% [markdown]
# # **Prepare Your Customized Training Data**

# %%
# %cd /content/Vintern
# Out:
# /content/Vintern

# %% [markdown]
# ## Single-Image Data
# First you need to create a dataset json file to describe each item of your dataset
#
# For single-image data, we use a **JSONL** file to store the data. Each entry is a dictionary organized in the following format. Note that each entry for single-image data must contain an image field, which is a string.
#
# The path in the image field is relative to the root field. Concatenating the root field and the image field gives the complete path to the image. It is recommended to include width and height information for each data sample for future use.
# ```
# {
#   "id": 0,
#   "image": "path/to/image.jpg",
#   "width": 111,
#   "height": 222,
#   "conversations": [
#     {"from": "human", "value": "\nuser input"},
#     {"from": "gpt", "value": "assistant output"},
#     {"from": "human", "value": "user input"},
#     {"from": "gpt", "value": "assistant output"}
#   ]
# }
# ```

# %% [markdown]
# Save image to image folder to get image_path to follow format of dataset

# %%
import os
from tqdm import tqdm
FOLDER_IMAGES = "/content/Viet-Receipt-VQA-images"
os.makedirs(FOLDER_IMAGES, exist_ok=True)

# %%
### Save image dataset
for i in tqdm(range(len(vi_receipt_dataset['train']))):
    image = vi_receipt_dataset['train'][i]['image']
    id = vi_receipt_dataset['train'][i]['id']

    #resize 448x448
    image = image.resize((448, 448)) # Just for saving vram
    image.save(f"{FOLDER_IMAGES}/{id}.jpg")
# Out:
# 100%|██████████| 2034/2034 [00:54<00:00, 37.53it/s]

# %% [markdown]
# Format each item data follow format above

# %%
import json

all_data = []

for item in tqdm(vi_receipt_dataset['train']):
    # Just 500 items for example
    if len(all_data) >= 50:
        break
    id = item['id']
    image = f"{FOLDER_IMAGES}/{item['id']}.jpg"
    width = item['image'].width
    height = item['image'].height
    conversations = [
            {"from": "human", "value": '\nTrích xuất thông tin hoá đơn trong ảnh.'},
            {"from": "gpt", "value": str(item["extractions"])}
        ]
    data = {
        "id": id,
        "image": image,
        "width": width,
        "height": height,
        "conversations": conversations
    }
    all_data.append(data)

print(len(all_data))
print(all_data[0:5])
# Out:
#   2%|▏         | 50/2034 [00:00<00:11, 170.02it/s]
# 50
# [{'id': 443, 'image': '/content/Viet-Receipt-VQA-images/443.jpg', 'width': 768, 'height': 1024, 'conversations': [{'from': 'human', 'value': '\nTrích xuất thông tin hoá đơn trong ảnh.'}, {'from': 'gpt', 'value': "{'Tên cửa hàng': 'Vincommerce', 'Địa chỉ': 'DA khu DCLB cóc 8, P. Cẩm Sơn, TP. Cẩm Phả, T. Quảng Ninh', 'Số điện thoại': '024.71066866-44561', 'Ngày bán': '14/08/2020', 'Giờ bán': '21:37', 'Số quầy': '001', 'Mã hóa đơn': 'H:00073344', 'NVBH': '09021213', 'Mặt hàng': 'Kem hướng sữa  riêng Vinamilk hộp 450ml', 'Đơn giá': '43.800', 'Số lượng': '1', 'Tổng tiền': '43.800', 'Tổng tiền à giảm': '0', 'Tiền khách trả': '43.800', 'Tiền mặt': '50.000', 'Tiền trả lại': '6.200'}"}]}, {'id': 7, 'image': '/content/Viet-Receipt-VQA-images/7.jpg', 'width': 1024, 'height': 1366, 'conversations': [{'from': 'human', 'value': '\nTrích xuất thông tin hoá đơn trong ảnh.'}, {'from': 'gpt', 'value': "{'Tên cửa hàng': 'Saigon Co.op', 'Chi nhánh': 'Co.op Food HN THE K-PARK', 'Mã số thuế': '0309129418-115', 'Số hoá đơn': '08459', 'Ngày': '20/09/2019', 'Giờ': '13:24:28', 'Tên sản phẩm': 'NGK Icesori beauti Pet 3', 'Số lượng': '1', 'Đơn giá': '14.000,00', 'Thành tiền': '14.000,00', 'Tổng tiền hàng': '14.000,00', 'Thuế GTGT 10%': '1.272,73', 'Tổng tiền thanh toán': '14.000,00', 'Mã HD': 'EODERACHNJANNY 13:24 25051'}"}]}, {'id': 305, 'image': '/content/Viet-Receipt-VQA-images/305.jpg', 'width': 1024, 'height': 1366, 'conversations': [{'from': 'human', 'value': '\nTrích xuất thông tin hoá đơn trong ảnh.'}, {'from': 'gpt', 'value': "{'Tên cửa hàng': 'Saigon Co.op', 'Chi nhánh': 'Food INN THE K-PARK', 'Số điện thoại': '0309129410-115', 'Ngày xuất hóa đơn': '20/09/2019', 'Giờ xuất hóa đơn': '10:23:26', 'Mã số hóa đơn': '2820271869', 'Tên khách hàng': 'NGUYEN HOANG ANH', 'Địa chỉ khách hàng': '912A.NGUYEN HOAN 382', 'Tổng tiền thanh toán': '38.774.000', 'Phương thức thanh toán': 'Tiền mặt', 'Tiền thanh toán': '100.000', 'Tiền thối lại': '-61.224.000'}"}]}, {'id': 763, 'image': '/content/Viet-Receipt-VQA-images/763.jpg', 'width': 1024, 'height': 1366, 'conversations': [{'from': 'human', 'value': '\nTrích xuất thông tin hoá đơn trong ảnh.'}, {'from': 'gpt', 'value': "{'Tên cửa hàng': 'Vincommerce', 'Địa chỉ': '165 Tô Hiệu tổ 1, P.Dịch Vọng, Q.Cầu Giấy, TP.Hà Nội', 'Số điện thoại': '024.71065866-23741', 'Ngày bán': '03/08/2020', 'Giờ bán': '11:15', 'Số quầy': '001', 'Mã hoá đơn': 'HB:00443523', 'Số NVBH': '05005113', 'Mặt hàng 1': 'LẠM HÀ Cốm Thạch Khô Hà Nội', 'Số lượng 1': '1', 'Đơn giá 1': '6.700', 'Đơn vị 1': 'hộp', 'Trọng lượng 1': '125G', 'Thành tiền 1': '6.700', 'Mặt hàng 2': 'Hạt Lạc Phú Hải', 'Số lượng 2': '1', 'Đơn giá 2': '33.000', 'Đơn vị 2': 'túi', 'Trọng lượng 2': '200g', 'Thành tiền 2': '33.000', 'Tổng tiền phải thanh toán': '39.700', 'Tổng tiền đã giảm': '0', 'Tiền khách trả': '39.700', 'Tiền mặt': '39.700', 'Tiền trả lại': '0', 'ID thẻ khách hàng': 'XXXXXXXXXXX9417', 'Điểm tích lũy': '1.000VNĐ=1 điểm', 'Số tham chiếu': '00237400100443523'}"}]}, {'id': 99, 'image': '/content/Viet-Receipt-VQA-images/99.jpg', 'width': 576, 'height': 1024, 'conversations': [{'from': 'human', 'value': '\nTrích xuất thông tin hoá đơn trong ảnh.'}, {'from': 'gpt', 'value': "{'Số hóa đơn': 'H:00046091', 'Số NVBH': '09024524', 'Ngày bán': '13/08/2020', 'Giờ bán': '14:51', 'Quầy': '001', 'Tên sản phẩm': 'VM HOME Dù cán cong C2', 'Mã sản phẩm': '2050000716775', 'Đơn giá': '199.000', 'Số lượng': '1', 'Thành tiền': '199.000', 'Tổng tiền phải thanh toán': '199.000', 'Tổng tiền giảm': '0', 'Tiền khách trả': '199.000', 'Tiền mặt': '200.000', 'Tiền trả lại': '1.000', 'Địa chỉ': 'VM+ QNH Tổ 8 Khu 38 Cẩm Trung \\nTổ 8, Khu 38, P. Cẩm Trung \\nTP. Cẩm Phả, T. Quảng Ninh \\n024.71066866-49871', 'Hotline': '02471066866', 'Website': 'vinmart.com'}"}]}]

# %%
### Write JSONL line
with open('/content/Vintern/internvl_chat/shell/data/viet-receipt-vqa.jsonl', 'w', encoding='utf-8') as f:
    for data in tqdm(all_data):
        f.write(json.dumps(data, ensure_ascii=False) + '\n')
# Out:
# 100%|██████████| 50/50 [00:00<00:00, 37936.90it/s]

# %% [markdown]
# ## Create meta file to manage the meta information of all datasets

# %% [markdown]
# After downloading the pre-trained model, prepare your customized SFT (Supervised Fine-Tuning) data. Create a JSON file in `internvl_chat/shell/data/` similar to [this example](https://github.com/OpenGVLab/InternVL/blob/main/internvl_chat/shell/data/internvl_1_2_finetune.json)
#
# The format for the JSON file should be:
#
# ```
# {
#   "your-custom-dataset-1": {
#     "root": "path/to/the/image/",
#     "annotation": "path/to/the/jsonl/annotation",
#     "data_augment": false,
#     "repeat_time": 1,
#     "length": "number of your data"
#   },
#   ...
# }```

# %%
metadata_datasets = {
  "vi-receipt-vqa": {
    "root": "/content/Viet-Receipt-VQA-images",
    "annotation": "/content/Vintern/internvl_chat/shell/data/viet-receipt-vqa.jsonl",
    "data_augment": False,
    "repeat_time": 1,
    "length": 50
  }
}

with open('/content/Vintern/internvl_chat/shell/data/custom_fintune_datasets.json', 'w', encoding='utf-8') as f:
    json.dump(metadata_datasets, f, ensure_ascii=False, indent=4)

# %% [markdown]
# # Training

# %% [markdown]
# ## LoRA fine-tuning

# %% [markdown]
# Fine-tune the pre-trained models using either the script for training the [full LLM](https://internvl.readthedocs.io/en/latest/internvl2.0/finetune.html#:~:text=script%20for%20training%20the%20full%20LLM) or the script for training the [LoRA adapter](https://github.com/OpenGVLab/InternVL/blob/main/internvl_chat/shell/internvl2.0/2nd_finetune/internvl2_1b_qwen2_0_5b_dynamic_res_2nd_finetune_lora.sh), depending on your available GPU resources.
#
# Before fine-tuning, set the --meta_path to the path of the JSON file you created in the previous step. The default pre-trained model path in these shell scripts is ./pretrained/InternVL2-1B.
#
# In the default settings, I have frozen the visual encoder. You can unfreeze it if needed. Generally, unfreezing the visual encoder will result in better performance.

# %% [markdown]
# Edit file `InternVL/internvl_chat/shell/internvl2.0/2nd_finetune/internvl2_1b_qwen2_0_5b_dynamic_res_2nd_finetune_lora.sh` for train LoRA LLM follow example below

# %%
train_bash_content = '''set -x

GPUS=${GPUS:-1}
BATCH_SIZE=${BATCH_SIZE:-1}
PER_DEVICE_BATCH_SIZE=${PER_DEVICE_BATCH_SIZE:-1}
GRADIENT_ACC=$((BATCH_SIZE / PER_DEVICE_BATCH_SIZE / GPUS))


export PYTHONPATH="${PYTHONPATH}:$(pwd)"
export MASTER_PORT=34229
export TF_CPP_MIN_LOG_LEVEL=3
export LAUNCHER=pytorch

OUTPUT_DIR='/content/work_dirs/internvl_chat_v2_0/Vintern_1B_v3_5_finetune_lora_viet_receipt_vqa'

if [ ! -d "$OUTPUT_DIR" ]; then
  mkdir -p "$OUTPUT_DIR"
fi

# number of gpus: 2
# batch size per gpu: 4
# gradient accumulation steps: 2
# total batch size: 16
# epoch: 1
torchrun \
  --nnodes=1 \
  --node_rank=0 \
  --master_addr=127.0.0.1 \
  --nproc_per_node=${GPUS} \
  --master_port=${MASTER_PORT} \
  internvl/train/internvl_chat_finetune.py \
  --model_name_or_path "/content/Vintern/pretrained/Vintern-1B-v3_5" \
  --conv_style "Hermes-2" \
  --output_dir ${OUTPUT_DIR} \
  --meta_path "/content/Vintern/internvl_chat/shell/data/custom_fintune_datasets.json" \
  --overwrite_output_dir True \
  --force_image_size 448 \
  --max_dynamic_patch 6 \
  --down_sample_ratio 0.5 \
  --drop_path_rate 0.0 \
  --freeze_llm True \
  --freeze_mlp True \
  --freeze_backbone True \
  --use_llm_lora 16 \
  --vision_select_layer -1 \
  --dataloader_num_workers 4 \
  --bf16 True \
  --num_train_epochs 1 \
  --per_device_train_batch_size ${PER_DEVICE_BATCH_SIZE} \
  --gradient_accumulation_steps ${GRADIENT_ACC} \
  --evaluation_strategy "no" \
  --save_strategy "steps" \
  --save_steps 500 \
  --save_total_limit 2 \
  --learning_rate 4e-5 \
  --weight_decay 0.01 \
  --warmup_ratio 0.03 \
  --lr_scheduler_type "cosine" \
  --logging_steps 10 \
  --max_seq_length 700 \
  --do_train True \
  --grad_checkpoint True \
  --group_by_length True \
  --dynamic_image_size True \
  --use_thumbnail True \
  --ps_version 'v2' \
  --deepspeed "zero_stage1_config.json" \
  --report_to "tensorboard" \
  2>&1 | tee -a "${OUTPUT_DIR}/training_log.txt"
'''

# %%
with open("/content/Vintern/internvl_chat/shell/internvl2.0/2nd_finetune/internvl2_1b_qwen2_0_5b_dynamic_res_2nd_finetune_lora.sh", "w") as text_file:
    text_file.write(train_bash_content)

# %% [markdown]
# Let's go training. It take about just 15 minutes with T4

# %%
# %cd /content/Vintern/internvl_chat
# !sh shell/internvl2.0/2nd_finetune/internvl2_1b_qwen2_0_5b_dynamic_res_2nd_finetune_lora.sh
# Out:
# /content/Vintern/internvl_chat
# + GPUS=1
# + BATCH_SIZE=1
# + PER_DEVICE_BATCH_SIZE=1
# + GRADIENT_ACC=1
# + pwd
# + export PYTHONPATH=/env/python:/content/Vintern/internvl_chat
# + export MASTER_PORT=34229
# + export TF_CPP_MIN_LOG_LEVEL=3
# + export LAUNCHER=pytorch
# + OUTPUT_DIR=/content/work_dirs/internvl_chat_v2_0/Vintern_1B_v3_5_finetune_lora_viet_receipt_vqa
# + [ ! -d /content/work_dirs/internvl_chat_v2_0/Vintern_1B_v3_5_finetune_lora_viet_receipt_vqa ]
# + mkdir -p /content/work_dirs/internvl_chat_v2_0/Vintern_1B_v3_5_finetune_lora_viet_receipt_vqa
# + torchrun --nnodes=1 --node_rank=0 --master_addr=127.0.0.1 --nproc_per_node=1 --master_port=34229 internvl/train/internvl_chat_finetune.py --model_name_or_path /content/Vintern/pretrained/Vintern-1B-v3_5 --conv_style Hermes-2 --output_dir /content/work_dirs/internvl_chat_v2_0/Vintern_1B_v3_5_finetune_lora_viet_receipt_vqa --meta_path /content/Vintern/internvl_chat/shell/data/custom_fintune_datasets.json --overwrite_output_dir True --force_image_size 448 --max_dynamic_patch 6 --down_sample_ratio 0.5 --drop_path_rate 0.0 --freeze_llm True --freeze_mlp True --freeze_backbone True --use_llm_lora 16 --vision_select_layer -1 --dataloader_num_workers 4 --bf16 True --num_train_epochs 1 --per_device_train_batch_size 1 --gradient_accumulation_steps 1 --evaluation_strategy no --save_strategy steps --save_steps 500 --save_total_limit 2 --learning_rate 4e-5 --weight_decay 0.01 --warmup_ratio 0.03 --lr_scheduler_type cosine --logging_steps 10 --max_seq_length 700 --do_train True --grad_checkpoint True --group_by_length True --dynamic_image_size True --use_thumbnail True --ps_version v2 --deepspeed zero_stage1_config.json --report_to tensorboard
# + tee -a /content/work_dirs/internvl_chat_v2_0/Vintern_1B_v3_5_finetune_lora_viet_receipt_vqa/training_log.txt
# [2025-06-28 15:07:31,584] [INFO] [real_accelerator.py:254:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-06-28 15:07:37,032] [INFO] [logging.py:107:log_dist] [Rank -1] [TorchCheckpointEngine] Initialized with serialization = False
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751123258.906266    2371 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751123258.922645    2371 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# petrel_client is not installed. If you read data locally instead of from ceph, ignore it.
# Replace train sampler!!
# petrel_client is not installed. Using PIL to load images.
# [2025-06-28 15:07:46,351] [INFO] [comm.py:675:init_distributed] cdb=None
# [2025-06-28 15:07:46,351] [INFO] [comm.py:706:init_distributed] Initializing TorchBackend in DeepSpeed with backend nccl
# 06/28/2025 15:07:46 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: True, 16-bits training: False
# 06/28/2025 15:07:46 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# accelerator_config={'split_batches': False, 'dispatch_batches': None, 'even_batches': True, 'use_seedable_sampler': True, 'non_blocking': False, 'gradient_accumulation_kwargs': None, 'use_configured_state': False},
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# average_tokens_across_devices=False,
# batch_eval_metrics=False,
# bf16=True,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=4,
# dataloader_persistent_workers=False,
# dataloader_pin_memory=True,
# dataloader_prefetch_factor=None,
# ddp_backend=None,
# ddp_broadcast_buffers=None,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=zero_stage1_config.json,
# disable_tqdm=False,
# dispatch_batches=None,
# do_eval=False,
# do_predict=False,
# do_train=True,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_do_concat_batches=True,
# eval_on_start=False,
# eval_steps=None,
# eval_strategy=IntervalStrategy.NO,
# eval_use_gather_object=False,
# evaluation_strategy=no,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# fsdp=[],
# fsdp_config={'min_num_params': 0, 'xla': False, 'xla_fsdp_v2': False, 'xla_fsdp_grad_ckpt': False},
# fsdp_min_num_params=0,
# fsdp_transformer_layer_cls_to_wrap=None,
# full_determinism=False,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# gradient_checkpointing_kwargs=None,
# greater_is_better=None,
# group_by_length=True,
# half_precision_backend=auto,
# hub_always_push=False,
# hub_model_id=None,
# hub_private_repo=None,
# hub_strategy=HubStrategy.EVERY_SAVE,
# hub_token=<HUB_TOKEN>,
# ignore_data_skip=False,
# include_for_metrics=[],
# include_inputs_for_metrics=False,
# include_num_input_tokens_seen=False,
# include_tokens_per_second=False,
# jit_mode_eval=False,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=4e-05,
# length_column_name=length,
# load_best_model_at_end=False,
# local_rank=0,
# log_level=passive,
# log_level_replica=warning,
# log_on_each_node=True,
# logging_dir=/content/work_dirs/internvl_chat_v2_0/Vintern_1B_v3_5_finetune_lora_viet_receipt_vqa/runs/Jun28_15-07-46_4b5e65ec0a71,
# logging_first_step=False,
# logging_nan_inf_filter=True,
# logging_steps=10,
# logging_strategy=IntervalStrategy.STEPS,
# lr_scheduler_kwargs={},
# lr_scheduler_type=SchedulerType.COSINE,
# max_grad_norm=1.0,
# max_steps=-1,
# metric_for_best_model=None,
# mp_parameters=,
# neftune_noise_alpha=None,
# no_cuda=False,
# num_train_epochs=1.0,
# optim=OptimizerNames.ADAMW_TORCH,
# optim_args=None,
# optim_target_modules=None,
# output_dir=/content/work_dirs/internvl_chat_v2_0/Vintern_1B_v3_5_finetune_lora_viet_receipt_vqa,
# overwrite_output_dir=True,
# past_index=-1,
# per_device_eval_batch_size=8,
# per_device_train_batch_size=1,
# prediction_loss_only=False,
# push_to_hub=False,
# push_to_hub_model_id=None,
# push_to_hub_organization=None,
# push_to_hub_token=<PUSH_TO_HUB_TOKEN>,
# ray_scope=last,
# remove_unused_columns=True,
# report_to=['tensorboard'],
# restore_callback_states_from_checkpoint=False,
# resume_from_checkpoint=None,
# run_name=/content/work_dirs/internvl_chat_v2_0/Vintern_1B_v3_5_finetune_lora_viet_receipt_vqa,
# save_on_each_node=False,
# save_only_model=False,
# save_safetensors=True,
# save_steps=500,
# save_strategy=SaveStrategy.STEPS,
# save_total_limit=2,
# seed=42,
# skip_memory_metrics=True,
# split_batches=None,
# tf32=None,
# torch_compile=False,
# torch_compile_backend=None,
# torch_compile_mode=None,
# torch_empty_cache_steps=None,
# torchdynamo=None,
# tpu_metrics_debug=False,
# tpu_num_cores=None,
# use_cpu=False,
# use_ipex=False,
# use_legacy_prediction_loop=False,
# use_liger_kernel=False,
# use_mps_device=False,
# warmup_ratio=0.03,
# warmup_steps=0,
# weight_decay=0.01,
# )
# 06/28/2025 15:07:46 - INFO - __main__ - Loading Tokenizer: /content/Vintern/pretrained/Vintern-1B-v3_5
# [INFO|tokenization_utils_base.py:2028] 2025-06-28 15:07:46,535 >> loading file vocab.json
# [INFO|tokenization_utils_base.py:2028] 2025-06-28 15:07:46,535 >> loading file merges.txt
# [INFO|tokenization_utils_base.py:2028] 2025-06-28 15:07:46,535 >> loading file added_tokens.json
# [INFO|tokenization_utils_base.py:2028] 2025-06-28 15:07:46,535 >> loading file special_tokens_map.json
# [INFO|tokenization_utils_base.py:2028] 2025-06-28 15:07:46,535 >> loading file tokenizer_config.json
# [INFO|tokenization_utils_base.py:2028] 2025-06-28 15:07:46,535 >> loading file tokenizer.json
# [INFO|tokenization_utils_base.py:2028] 2025-06-28 15:07:46,535 >> loading file chat_template.jinja
# [INFO|tokenization_utils_base.py:2300] 2025-06-28 15:07:46,795 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 06/28/2025 15:07:46 - INFO - __main__ - Loading InternVLChatModel...
# [INFO|configuration_utils.py:693] 2025-06-28 15:07:46,804 >> loading configuration file /content/Vintern/pretrained/Vintern-1B-v3_5/config.json
# [INFO|configuration_utils.py:762] 2025-06-28 15:07:46,805 >> Model config InternVLChatConfig {
#   "_commit_hash": null,
#   "architectures": [
#     "InternVLChatModel"
#   ],
#   "auto_map": {
#     "AutoConfig": "5CD-AI/Vintern-1B-v3_5--configuration_internvl_chat.InternVLChatConfig",
#     "AutoModel": "5CD-AI/Vintern-1B-v3_5--modeling_internvl_chat.InternVLChatModel",
#     "AutoModelForCausalLM": "5CD-AI/Vintern-1B-v3_5--modeling_internvl_chat.InternVLChatModel"
#   },
#   "downsample_ratio": 0.5,
#   "dynamic_image_size": true,
#   "force_image_size": 448,
#   "llm_config": {
#     "_attn_implementation_autoset": false,
#     "_name_or_path": "Qwen/Qwen2.5-0.5B-Instruct",
#     "add_cross_attention": false,
#     "architectures": [
#       "Qwen2ForCausalLM"
#     ],
#     "attention_dropout": 0.0,
#     "bad_words_ids": null,
#     "begin_suppress_tokens": null,
#     "bos_token_id": 151643,
#     "chunk_size_feed_forward": 0,
#     "cross_attention_hidden_size": null,
#     "decoder_start_token_id": null,
#     "diversity_penalty": 0.0,
#     "do_sample": false,
#     "early_stopping": false,
#     "encoder_no_repeat_ngram_size": 0,
#     "eos_token_id": 151645,
#     "exponential_decay_length_penalty": null,
#     "finetuning_task": null,
#     "forced_bos_token_id": null,
#     "forced_eos_token_id": null,
#     "hidden_act": "silu",
#     "hidden_size": 896,
#     "id2label": {
#       "0": "LABEL_0",
#       "1": "LABEL_1"
#     },
#     "initializer_range": 0.02,
#     "intermediate_size": 4864,
#     "is_decoder": false,
#     "is_encoder_decoder": false,
#     "label2id": {
#       "LABEL_0": 0,
#       "LABEL_1": 1
#     },
#     "length_penalty": 1.0,
#     "max_length": 20,
#     "max_position_embeddings": 32768,
#     "max_window_layers": 21,
#     "min_length": 0,
#     "model_type": "qwen2",
#     "no_repeat_ngram_size": 0,
#     "num_attention_heads": 14,
#     "num_beam_groups": 1,
#     "num_beams": 1,
#     "num_hidden_layers": 24,
#     "num_key_value_heads": 2,
#     "num_return_sequences": 1,
#     "output_attentions": false,
#     "output_hidden_states": false,
#     "output_scores": false,
#     "pad_token_id": null,
#     "prefix": null,
#     "problem_type": null,
#     "pruned_heads": {},
#     "remove_invalid_values": false,
#     "repetition_penalty": 1.0,
#     "return_dict": true,
#     "return_dict_in_generate": false,
#     "rms_norm_eps": 1e-06,
#     "rope_scaling": null,
#     "rope_theta": 1000000.0,
#     "sep_token_id": null,
#     "sliding_window": null,
#     "suppress_tokens": null,
#     "task_specific_params": null,
#     "temperature": 1.0,
#     "tf_legacy_loss": false,
#     "tie_encoder_decoder": false,
#     "tie_word_embeddings": false,
#     "tokenizer_class": null,
#     "top_k": 50,
#     "top_p": 1.0,
#     "torch_dtype": "bfloat16",
#     "torchscript": false,
#     "transformers_version": "4.47.0",
#     "typical_p": 1.0,
#     "use_bfloat16": true,
#     "use_cache": false,
#     "use_sliding_window": false,
#     "vocab_size": 151674
#   },
#   "max_dynamic_patch": 4,
#   "min_dynamic_patch": 1,
#   "model_type": "internvl_chat",
#   "pad2square": false,
#   "ps_version": "v2",
#   "select_layer": -1,
#   "template": "Hermes-2",
#   "torch_dtype": "float32",
#   "transformers_version": null,
#   "use_backbone_lora": 0,
#   "use_llm_lora": 0,
#   "use_thumbnail": true,
#   "vision_config": {
#     "_attn_implementation_autoset": false,
#     "_name_or_path": "",
#     "add_cross_attention": false,
#     "architectures": [
#       "InternVisionModel"
#     ],
#     "attention_dropout": 0.0,
#     "bad_words_ids": null,
#     "begin_suppress_tokens": null,
#     "bos_token_id": null,
#     "chunk_size_feed_forward": 0,
#     "cross_attention_hidden_size": null,
#     "decoder_start_token_id": null,
#     "diversity_penalty": 0.0,
#     "do_sample": false,
#     "drop_path_rate": 0.0,
#     "dropout": 0.0,
#     "early_stopping": false,
#     "encoder_no_repeat_ngram_size": 0,
#     "eos_token_id": null,
#     "exponential_decay_length_penalty": null,
#     "finetuning_task": null,
#     "forced_bos_token_id": null,
#     "forced_eos_token_id": null,
#     "hidden_act": "gelu",
#     "hidden_size": 1024,
#     "id2label": {
#       "0": "LABEL_0",
#       "1": "LABEL_1"
#     },
#     "image_size": 448,
#     "initializer_factor": 1.0,
#     "initializer_range": 0.02,
#     "intermediate_size": 4096,
#     "is_decoder": false,
#     "is_encoder_decoder": false,
#     "label2id": {
#       "LABEL_0": 0,
#       "LABEL_1": 1
#     },
#     "layer_norm_eps": 1e-06,
#     "length_penalty": 1.0,
#     "max_length": 20,
#     "min_length": 0,
#     "model_type": "intern_vit_6b",
#     "no_repeat_ngram_size": 0,
#     "norm_type": "layer_norm",
#     "num_attention_heads": 16,
#     "num_beam_groups": 1,
#     "num_beams": 1,
#     "num_channels": 3,
#     "num_hidden_layers": 24,
#     "num_return_sequences": 1,
#     "output_attentions": false,
#     "output_hidden_states": false,
#     "output_scores": false,
#     "pad_token_id": null,
#     "patch_size": 14,
#     "prefix": null,
#     "problem_type": null,
#     "pruned_heads": {},
#     "qk_normalization": false,
#     "qkv_bias": true,
#     "remove_invalid_values": false,
#     "repetition_penalty": 1.0,
#     "return_dict": true,
#     "return_dict_in_generate": false,
#     "sep_token_id": null,
#     "suppress_tokens": null,
#     "task_specific_params": null,
#     "temperature": 1.0,
#     "tf_legacy_loss": false,
#     "tie_encoder_decoder": false,
#     "tie_word_embeddings": true,
#     "tokenizer_class": null,
#     "top_k": 50,
#     "top_p": 1.0,
#     "torch_dtype": "bfloat16",
#     "torchscript": false,
#     "transformers_version": "4.47.0",
#     "typical_p": 1.0,
#     "use_bfloat16": true,
#     "use_flash_attn": false
#   }
# }
#
# 06/28/2025 15:07:46 - INFO - __main__ - Using flash_attention_2 for LLaMA
# [INFO|modeling_utils.py:3950] 2025-06-28 15:07:46,806 >> loading weights file /content/Vintern/pretrained/Vintern-1B-v3_5/model.safetensors
# [INFO|modeling_utils.py:1641] 2025-06-28 15:07:46,832 >> Instantiating InternVLChatModel model under default dtype torch.bfloat16.
# [INFO|configuration_utils.py:1140] 2025-06-28 15:07:46,833 >> Generate config GenerationConfig {}
#
# [INFO|configuration_utils.py:1140] 2025-06-28 15:07:46,883 >> Generate config GenerationConfig {
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "use_cache": false
# }
#
# [INFO|modeling_utils.py:4849] 2025-06-28 15:08:03,363 >> All model checkpoint weights were used when initializing InternVLChatModel.
#
# [INFO|modeling_utils.py:4857] 2025-06-28 15:08:03,364 >> All the weights of InternVLChatModel were initialized from the model checkpoint at /content/Vintern/pretrained/Vintern-1B-v3_5.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use InternVLChatModel for predictions without further training.
# [INFO|configuration_utils.py:1093] 2025-06-28 15:08:03,368 >> loading configuration file /content/Vintern/pretrained/Vintern-1B-v3_5/generation_config.json
# [INFO|configuration_utils.py:1140] 2025-06-28 15:08:03,368 >> Generate config GenerationConfig {
#   "eos_token_id": [
#     151644,
#     151645,
#     151643
#   ]
# }
#
# 06/28/2025 15:08:03 - INFO - __main__ - Finished
# 06/28/2025 15:08:03 - INFO - __main__ - model.config.force_image_size: 448
# 06/28/2025 15:08:03 - INFO - __main__ - data_args.force_image_size: 448
# 06/28/2025 15:08:03 - INFO - __main__ - model.config.vision_config.image_size: 448
# 06/28/2025 15:08:03 - INFO - __main__ - [Dataset] num_image_token: 256
# 06/28/2025 15:08:03 - INFO - __main__ - [Dataset] dynamic_image_size: True
# 06/28/2025 15:08:03 - INFO - __main__ - [Dataset] use_thumbnail: True
# 06/28/2025 15:08:03 - INFO - __main__ - [Dataset] min_dynamic_patch: 1, max_dynamic_patch: 6
# 06/28/2025 15:08:03 - INFO - __main__ - Formatting inputs...Skip in lazy mode
# [WARNING|tokenization_utils_base.py:3928] 2025-06-28 15:08:03,906 >> Token indices sequence length is longer than the specified maximum sequence length for this model (779 > 700). Running this sequence through the model will result in indexing errors
# 06/28/2025 15:08:04 - INFO - __main__ - Add dataset: vi-receipt-vqa with length: 50
# trainable params: 8,798,208 || all params: 638,496,128 || trainable%: 1.3780
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.0.self_attn.q_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.0.self_attn.q_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.0.self_attn.k_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.0.self_attn.k_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.0.self_attn.v_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.0.self_attn.v_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.0.self_attn.o_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.0.self_attn.o_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.0.mlp.gate_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.0.mlp.gate_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.0.mlp.up_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.0.mlp.up_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.0.mlp.down_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.0.mlp.down_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.1.self_attn.q_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.1.self_attn.q_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.1.self_attn.k_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.1.self_attn.k_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.1.self_attn.v_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.1.self_attn.v_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.1.self_attn.o_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.1.self_attn.o_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.1.mlp.gate_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.1.mlp.gate_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.1.mlp.up_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.1.mlp.up_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.1.mlp.down_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.1.mlp.down_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.2.self_attn.q_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.2.self_attn.q_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.2.self_attn.k_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.2.self_attn.k_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.2.self_attn.v_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.2.self_attn.v_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.2.self_attn.o_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.2.self_attn.o_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.2.mlp.gate_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.2.mlp.gate_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.2.mlp.up_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.2.mlp.up_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.2.mlp.down_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.2.mlp.down_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.3.self_attn.q_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.3.self_attn.q_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.3.self_attn.k_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.3.self_attn.k_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.3.self_attn.v_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.3.self_attn.v_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.3.self_attn.o_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.3.self_attn.o_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.3.mlp.gate_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.3.mlp.gate_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.3.mlp.up_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.3.mlp.up_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.3.mlp.down_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.3.mlp.down_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.4.self_attn.q_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.4.self_attn.q_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.4.self_attn.k_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.4.self_attn.k_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.4.self_attn.v_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.4.self_attn.v_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.4.self_attn.o_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.4.self_attn.o_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.4.mlp.gate_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.4.mlp.gate_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.4.mlp.up_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.4.mlp.up_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.4.mlp.down_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.4.mlp.down_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.5.self_attn.q_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.5.self_attn.q_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.5.self_attn.k_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.5.self_attn.k_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.5.self_attn.v_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.5.self_attn.v_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.5.self_attn.o_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.5.self_attn.o_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.5.mlp.gate_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.5.mlp.gate_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.5.mlp.up_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.5.mlp.up_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.5.mlp.down_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.5.mlp.down_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.6.self_attn.q_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.6.self_attn.q_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.6.self_attn.k_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.6.self_attn.k_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.6.self_attn.v_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.6.self_attn.v_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.6.self_attn.o_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.6.self_attn.o_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.6.mlp.gate_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.6.mlp.gate_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.6.mlp.up_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.6.mlp.up_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.6.mlp.down_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.6.mlp.down_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.7.self_attn.q_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.7.self_attn.q_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.7.self_attn.k_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.7.self_attn.k_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.7.self_attn.v_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.7.self_attn.v_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.7.self_attn.o_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.7.self_attn.o_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.7.mlp.gate_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.7.mlp.gate_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.7.mlp.up_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.7.mlp.up_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.7.mlp.down_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.7.mlp.down_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.8.self_attn.q_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.8.self_attn.q_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.8.self_attn.k_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.8.self_attn.k_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.8.self_attn.v_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.8.self_attn.v_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.8.self_attn.o_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.8.self_attn.o_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.8.mlp.gate_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.8.mlp.gate_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.8.mlp.up_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.8.mlp.up_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.8.mlp.down_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.8.mlp.down_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.9.self_attn.q_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.9.self_attn.q_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.9.self_attn.k_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.9.self_attn.k_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.9.self_attn.v_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.9.self_attn.v_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.9.self_attn.o_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.9.self_attn.o_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.9.mlp.gate_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.9.mlp.gate_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.9.mlp.up_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.9.mlp.up_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.9.mlp.down_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.9.mlp.down_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.10.self_attn.q_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.10.self_attn.q_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.10.self_attn.k_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.10.self_attn.k_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.10.self_attn.v_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.10.self_attn.v_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.10.self_attn.o_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.10.self_attn.o_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.10.mlp.gate_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.10.mlp.gate_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.10.mlp.up_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.10.mlp.up_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.10.mlp.down_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.10.mlp.down_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.11.self_attn.q_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.11.self_attn.q_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.11.self_attn.k_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.11.self_attn.k_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.11.self_attn.v_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.11.self_attn.v_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.11.self_attn.o_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.11.self_attn.o_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.11.mlp.gate_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.11.mlp.gate_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.11.mlp.up_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.11.mlp.up_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.11.mlp.down_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.11.mlp.down_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.12.self_attn.q_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.12.self_attn.q_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.12.self_attn.k_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.12.self_attn.k_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.12.self_attn.v_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.12.self_attn.v_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.12.self_attn.o_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.12.self_attn.o_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.12.mlp.gate_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.12.mlp.gate_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.12.mlp.up_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.12.mlp.up_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.12.mlp.down_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.12.mlp.down_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.13.self_attn.q_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.13.self_attn.q_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.13.self_attn.k_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.13.self_attn.k_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.13.self_attn.v_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.13.self_attn.v_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.13.self_attn.o_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.13.self_attn.o_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.13.mlp.gate_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.13.mlp.gate_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.13.mlp.up_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.13.mlp.up_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.13.mlp.down_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.13.mlp.down_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.14.self_attn.q_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.14.self_attn.q_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.14.self_attn.k_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.14.self_attn.k_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.14.self_attn.v_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.14.self_attn.v_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.14.self_attn.o_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.14.self_attn.o_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.14.mlp.gate_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.14.mlp.gate_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.14.mlp.up_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.14.mlp.up_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.14.mlp.down_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.14.mlp.down_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.15.self_attn.q_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.15.self_attn.q_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.15.self_attn.k_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.15.self_attn.k_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.15.self_attn.v_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.15.self_attn.v_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.15.self_attn.o_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.15.self_attn.o_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.15.mlp.gate_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.15.mlp.gate_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.15.mlp.up_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.15.mlp.up_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.15.mlp.down_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.15.mlp.down_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.16.self_attn.q_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.16.self_attn.q_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.16.self_attn.k_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.16.self_attn.k_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.16.self_attn.v_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.16.self_attn.v_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.16.self_attn.o_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.16.self_attn.o_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.16.mlp.gate_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.16.mlp.gate_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.16.mlp.up_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.16.mlp.up_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.16.mlp.down_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.16.mlp.down_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.17.self_attn.q_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.17.self_attn.q_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.17.self_attn.k_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.17.self_attn.k_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.17.self_attn.v_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.17.self_attn.v_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.17.self_attn.o_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.17.self_attn.o_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.17.mlp.gate_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.17.mlp.gate_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.17.mlp.up_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.17.mlp.up_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.17.mlp.down_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.17.mlp.down_proj.lora_B.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.18.self_attn.q_proj.lora_A.default.weight
# 06/28/2025 15:08:06 - INFO - __main__ - language_model.base_model.model.model.layers.18.self_attn.q_proj.lora_B.default.weight
# ...
# [2025-06-28 15:11:00,535] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.00 | optimizer_gradients: 1.30 | optimizer_step: 1.46
# [2025-06-28 15:11:00,536] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd_microstep: 585.75 | bwd_microstep: 524.86 | bwd_inner_microstep: 515.10 | bwd_allreduce_microstep: 9.63 | step_microstep: 15.35
# [2025-06-28 15:11:00,536] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd: 585.73 | bwd: 524.87 | bwd_inner: 515.14 | bwd_allreduce: 9.64 | step: 15.36
#  68%|██████▊   | 34/50 [01:57<00:21,  1.32s/it]dynamic ViT batch size: 1, images per sample: 1.0, dynamic token length: 700
# [2025-06-28 15:11:02,027] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.00 | optimizer_gradients: 1.29 | optimizer_step: 1.46
# [2025-06-28 15:11:02,028] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd_microstep: 687.44 | bwd_microstep: 764.12 | bwd_inner_microstep: 753.10 | bwd_allreduce_microstep: 10.90 | step_microstep: 14.83
# [2025-06-28 15:11:02,028] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd: 687.42 | bwd: 764.13 | bwd_inner: 753.13 | bwd_allreduce: 10.92 | step: 14.83
#  70%|███████   | 35/50 [01:58<00:20,  1.37s/it]dynamic ViT batch size: 1, images per sample: 1.0, dynamic token length: 533
# [2025-06-28 15:11:03,294] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.00 | optimizer_gradients: 1.85 | optimizer_step: 1.45
# [2025-06-28 15:11:03,294] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd_microstep: 622.21 | bwd_microstep: 602.26 | bwd_inner_microstep: 592.45 | bwd_allreduce_microstep: 9.70 | step_microstep: 16.54
# [2025-06-28 15:11:03,294] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd: 622.19 | bwd: 602.27 | bwd_inner: 592.48 | bwd_allreduce: 9.71 | step: 16.55
#  72%|███████▏  | 36/50 [02:00<00:18,  1.34s/it]dynamic ViT batch size: 1, images per sample: 1.0, dynamic token length: 611
# [2025-06-28 15:11:04,663] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.00 | optimizer_gradients: 1.28 | optimizer_step: 1.45
# [2025-06-28 15:11:04,664] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd_microstep: 653.39 | bwd_microstep: 676.50 | bwd_inner_microstep: 666.43 | bwd_allreduce_microstep: 9.96 | step_microstep: 15.14
# [2025-06-28 15:11:04,664] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd: 653.37 | bwd: 676.51 | bwd_inner: 666.46 | bwd_allreduce: 9.97 | step: 15.15
#  74%|███████▍  | 37/50 [02:01<00:17,  1.35s/it]dynamic ViT batch size: 1, images per sample: 1.0, dynamic token length: 508
# [2025-06-28 15:11:05,854] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.00 | optimizer_gradients: 1.26 | optimizer_step: 1.47
# [2025-06-28 15:11:05,855] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd_microstep: 585.49 | bwd_microstep: 565.03 | bwd_inner_microstep: 554.91 | bwd_allreduce_microstep: 10.03 | step_microstep: 14.93
# [2025-06-28 15:11:05,855] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd: 585.45 | bwd: 565.04 | bwd_inner: 554.93 | bwd_allreduce: 10.03 | step: 14.93
#  76%|███████▌  | 38/50 [02:02<00:15,  1.30s/it]dynamic ViT batch size: 1, images per sample: 1.0, dynamic token length: 627
# [2025-06-28 15:11:07,234] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.00 | optimizer_gradients: 1.25 | optimizer_step: 1.45
# [2025-06-28 15:11:07,234] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd_microstep: 654.44 | bwd_microstep: 685.34 | bwd_inner_microstep: 675.43 | bwd_allreduce_microstep: 9.80 | step_microstep: 14.93
# [2025-06-28 15:11:07,235] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd: 654.41 | bwd: 685.35 | bwd_inner: 675.46 | bwd_allreduce: 9.81 | step: 14.94
#  78%|███████▊  | 39/50 [02:04<00:14,  1.33s/it]dynamic ViT batch size: 1, images per sample: 1.0, dynamic token length: 611
# [2025-06-28 15:11:08,596] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.00 | optimizer_gradients: 1.23 | optimizer_step: 1.46
# [2025-06-28 15:11:08,596] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd_microstep: 650.45 | bwd_microstep: 671.57 | bwd_inner_microstep: 661.85 | bwd_allreduce_microstep: 9.62 | step_microstep: 14.56
# [2025-06-28 15:11:08,597] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd: 650.43 | bwd: 671.58 | bwd_inner: 661.88 | bwd_allreduce: 9.63 | step: 14.57
# {'loss': 0.732, 'grad_norm': 1.9870737791061401, 'learning_rate': 4.132933194175299e-06, 'epoch': 0.8}
#  80%|████████  | 40/50 [02:05<00:13,  1.34s/it]dynamic ViT batch size: 1, images per sample: 1.0, dynamic token length: 611
# [2025-06-28 15:11:09,968] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.00 | optimizer_gradients: 2.00 | optimizer_step: 1.46
# [2025-06-28 15:11:09,968] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd_microstep: 648.74 | bwd_microstep: 675.27 | bwd_inner_microstep: 660.53 | bwd_allreduce_microstep: 14.60 | step_microstep: 21.73
# [2025-06-28 15:11:09,969] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd: 648.72 | bwd: 675.28 | bwd_inner: 660.56 | bwd_allreduce: 14.61 | step: 21.74
#  82%|████████▏ | 41/50 [02:06<00:12,  1.35s/it]dynamic ViT batch size: 1, images per sample: 1.0, dynamic token length: 669
# [2025-06-28 15:11:11,430] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.00 | optimizer_gradients: 1.83 | optimizer_step: 1.47
# [2025-06-28 15:11:11,431] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd_microstep: 679.49 | bwd_microstep: 725.10 | bwd_inner_microstep: 710.37 | bwd_allreduce_microstep: 14.57 | step_microstep: 26.34
# [2025-06-28 15:11:11,431] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd: 679.47 | bwd: 725.12 | bwd_inner: 710.42 | bwd_allreduce: 14.58 | step: 26.35
#  84%|████████▍ | 42/50 [02:08<00:11,  1.38s/it]dynamic ViT batch size: 1, images per sample: 1.0, dynamic token length: 658
# [2025-06-28 15:11:12,862] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.00 | optimizer_gradients: 1.55 | optimizer_step: 1.46
# [2025-06-28 15:11:12,862] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd_microstep: 675.11 | bwd_microstep: 710.32 | bwd_inner_microstep: 700.45 | bwd_allreduce_microstep: 9.76 | step_microstep: 15.26
# [2025-06-28 15:11:12,863] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd: 675.09 | bwd: 710.33 | bwd_inner: 700.49 | bwd_allreduce: 9.76 | step: 15.27
#  86%|████████▌ | 43/50 [02:09<00:09,  1.40s/it]dynamic ViT batch size: 1, images per sample: 1.0, dynamic token length: 700
# [2025-06-28 15:11:14,337] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.00 | optimizer_gradients: 1.29 | optimizer_step: 1.46
# [2025-06-28 15:11:14,338] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd_microstep: 685.29 | bwd_microstep: 755.15 | bwd_inner_microstep: 744.18 | bwd_allreduce_microstep: 10.81 | step_microstep: 16.42
# [2025-06-28 15:11:14,338] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd: 685.28 | bwd: 755.16 | bwd_inner: 744.21 | bwd_allreduce: 10.85 | step: 16.42
#  88%|████████▊ | 44/50 [02:11<00:08,  1.42s/it]dynamic ViT batch size: 1, images per sample: 1.0, dynamic token length: 553
# [2025-06-28 15:11:15,612] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.00 | optimizer_gradients: 1.33 | optimizer_step: 1.46
# [2025-06-28 15:11:15,612] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd_microstep: 624.00 | bwd_microstep: 615.58 | bwd_inner_microstep: 605.69 | bwd_allreduce_microstep: 9.79 | step_microstep: 15.37
# [2025-06-28 15:11:15,612] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd: 623.99 | bwd: 615.59 | bwd_inner: 605.72 | bwd_allreduce: 9.80 | step: 15.38
#  90%|█████████ | 45/50 [02:12<00:06,  1.38s/it]dynamic ViT batch size: 1, images per sample: 1.0, dynamic token length: 623
# [2025-06-28 15:11:16,966] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.00 | optimizer_gradients: 1.21 | optimizer_step: 1.47
# [2025-06-28 15:11:16,966] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd_microstep: 648.00 | bwd_microstep: 672.38 | bwd_inner_microstep: 662.17 | bwd_allreduce_microstep: 10.12 | step_microstep: 14.97
# [2025-06-28 15:11:16,966] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd: 647.99 | bwd: 672.39 | bwd_inner: 662.20 | bwd_allreduce: 10.12 | step: 14.98
#  92%|█████████▏| 46/50 [02:13<00:05,  1.37s/it]dynamic ViT batch size: 1, images per sample: 1.0, dynamic token length: 601
# [2025-06-28 15:11:18,301] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.00 | optimizer_gradients: 1.28 | optimizer_step: 1.46
# [2025-06-28 15:11:18,301] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd_microstep: 643.64 | bwd_microstep: 655.64 | bwd_inner_microstep: 644.46 | bwd_allreduce_microstep: 11.06 | step_microstep: 16.40
# [2025-06-28 15:11:18,302] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd: 643.63 | bwd: 655.65 | bwd_inner: 644.50 | bwd_allreduce: 11.07 | step: 16.41
#  94%|█████████▍| 47/50 [02:15<00:04,  1.36s/it]dynamic ViT batch size: 1, images per sample: 1.0, dynamic token length: 557
# [2025-06-28 15:11:19,570] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.00 | optimizer_gradients: 1.33 | optimizer_step: 1.47
# [2025-06-28 15:11:19,571] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd_microstep: 620.02 | bwd_microstep: 613.70 | bwd_inner_microstep: 603.22 | bwd_allreduce_microstep: 10.37 | step_microstep: 16.28
# [2025-06-28 15:11:19,571] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd: 619.99 | bwd: 613.71 | bwd_inner: 603.25 | bwd_allreduce: 10.37 | step: 16.30
#  96%|█████████▌| 48/50 [02:16<00:02,  1.33s/it]dynamic ViT batch size: 1, images per sample: 1.0, dynamic token length: 645
# [2025-06-28 15:11:20,981] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.00 | optimizer_gradients: 1.25 | optimizer_step: 1.46
# [2025-06-28 15:11:20,982] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd_microstep: 675.29 | bwd_microstep: 702.71 | bwd_inner_microstep: 692.92 | bwd_allreduce_microstep: 9.68 | step_microstep: 14.65
# [2025-06-28 15:11:20,982] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd: 675.27 | bwd: 702.72 | bwd_inner: 692.96 | bwd_allreduce: 9.68 | step: 14.65
#  98%|█████████▊| 49/50 [02:17<00:01,  1.36s/it]petrel_client is not installed. If you read data locally instead of from ceph, ignore it.
# Replace train sampler!!
# petrel_client is not installed. Using PIL to load images.
# petrel_client is not installed. If you read data locally instead of from ceph, ignore it.
# Replace train sampler!!
# petrel_client is not installed. Using PIL to load images.
# petrel_client is not installed. If you read data locally instead of from ceph, ignore it.
# Replace train sampler!!
# petrel_client is not installed. Using PIL to load images.
# petrel_client is not installed. If you read data locally instead of from ceph, ignore it.
# Replace train sampler!!
# petrel_client is not installed. Using PIL to load images.
# dynamic ViT batch size: 1, images per sample: 1.0, dynamic token length: 584
# [2025-06-28 15:11:33,413] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | optimizer_allgather: 0.00 | optimizer_gradients: 9.76 | optimizer_step: 1.51
# [2025-06-28 15:11:33,424] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd_microstep: 1391.49 | bwd_microstep: 1348.14 | bwd_inner_microstep: 1317.59 | bwd_allreduce_microstep: 30.41 | step_microstep: 69.79
# [2025-06-28 15:11:33,424] [INFO] [logging.py:107:log_dist] [Rank 0] time (ms) | fwd: 1391.47 | bwd: 1348.16 | bwd_inner: 1317.63 | bwd_allreduce: 30.40 | step: 69.79
# {'loss': 0.5964, 'grad_norm': 2.078878879547119, 'learning_rate': 0.0, 'epoch': 1.0}
# 100%|██████████| 50/50 [02:30<00:00,  4.69s/it][INFO|trainer.py:3888] 2025-06-28 15:11:34,793 >> Saving model checkpoint to /content/work_dirs/internvl_chat_v2_0/Vintern_1B_v3_5_finetune_lora_viet_receipt_vqa/checkpoint-50
# [INFO|configuration_utils.py:419] 2025-06-28 15:11:34,799 >> Configuration saved in /content/work_dirs/internvl_chat_v2_0/Vintern_1B_v3_5_finetune_lora_viet_receipt_vqa/checkpoint-50/config.json
# [INFO|configuration_utils.py:909] 2025-06-28 15:11:34,800 >> Configuration saved in /content/work_dirs/internvl_chat_v2_0/Vintern_1B_v3_5_finetune_lora_viet_receipt_vqa/checkpoint-50/generation_config.json
# [INFO|modeling_utils.py:3042] 2025-06-28 15:12:41,825 >> Model weights saved in /content/work_dirs/internvl_chat_v2_0/Vintern_1B_v3_5_finetune_lora_viet_receipt_vqa/checkpoint-50/model.safetensors
# [INFO|tokenization_utils_base.py:2485] 2025-06-28 15:12:41,872 >> tokenizer config file saved in /content/work_dirs/internvl_chat_v2_0/Vintern_1B_v3_5_finetune_lora_viet_receipt_vqa/checkpoint-50/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2494] 2025-06-28 15:12:41,873 >> Special tokens file saved in /content/work_dirs/internvl_chat_v2_0/Vintern_1B_v3_5_finetune_lora_viet_receipt_vqa/checkpoint-50/special_tokens_map.json
# [INFO|tokenization_utils_base.py:2545] 2025-06-28 15:12:41,873 >> added tokens file saved in /content/work_dirs/internvl_chat_v2_0/Vintern_1B_v3_5_finetune_lora_viet_receipt_vqa/checkpoint-50/added_tokens.json
# [2025-06-28 15:12:42,113] [INFO] [logging.py:107:log_dist] [Rank 0] [Torch] Checkpoint global_step50 is begin to save!
# [2025-06-28 15:12:42,137] [INFO] [logging.py:107:log_dist] [Rank 0] Saving model checkpoint: /content/work_dirs/internvl_chat_v2_0/Vintern_1B_v3_5_finetune_lora_viet_receipt_vqa/checkpoint-50/global_step50/mp_rank_00_model_states.pt
# [INFO|trainer.py:2634] 2025-06-28 15:14:01,943 >>
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# {'train_runtime': 298.7952, 'train_samples_per_second': 0.167, 'train_steps_per_second': 0.167, 'train_loss': 0.570517578125, 'epoch': 1.0}
# 100%|██████████| 50/50 [04:58<00:00,  5.98s/it]
# [INFO|trainer.py:3888] 2025-06-28 15:14:02,493 >> Saving model checkpoint to /content/work_dirs/internvl_chat_v2_0/Vintern_1B_v3_5_finetune_lora_viet_receipt_vqa
# [INFO|configuration_utils.py:419] 2025-06-28 15:14:02,499 >> Configuration saved in /content/work_dirs/internvl_chat_v2_0/Vintern_1B_v3_5_finetune_lora_viet_receipt_vqa/config.json
# [INFO|configuration_utils.py:909] 2025-06-28 15:14:02,499 >> Configuration saved in /content/work_dirs/internvl_chat_v2_0/Vintern_1B_v3_5_finetune_lora_viet_receipt_vqa/generation_config.json
# [INFO|modeling_utils.py:3042] 2025-06-28 15:15:52,272 >> Model weights saved in /content/work_dirs/internvl_chat_v2_0/Vintern_1B_v3_5_finetune_lora_viet_receipt_vqa/model.safetensors
# [INFO|tokenization_utils_base.py:2485] 2025-06-28 15:15:52,278 >> tokenizer config file saved in /content/work_dirs/internvl_chat_v2_0/Vintern_1B_v3_5_finetune_lora_viet_receipt_vqa/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2494] 2025-06-28 15:15:52,278 >> Special tokens file saved in /content/work_dirs/internvl_chat_v2_0/Vintern_1B_v3_5_finetune_lora_viet_receipt_vqa/special_tokens_map.json
# [INFO|tokenization_utils_base.py:2545] 2025-06-28 15:15:52,279 >> added tokens file saved in /content/work_dirs/internvl_chat_v2_0/Vintern_1B_v3_5_finetune_lora_viet_receipt_vqa/added_tokens.json
# ***** train metrics *****
#   epoch                    =         1.0
#   total_flos               = 136448390GF
#   train_loss               =      0.5705
#   train_runtime            =  0:04:58.79
#   train_samples            =          50
#   train_samples_per_second =       0.167
#   train_steps_per_second   =       0.167
# [rank0]:[W628 15:15:54.584073315 ProcessGroupNCCL.cpp:1496] Warning: WARNING: destroy_process_group() was not called before program exit, which can leak resources. For more info, please see https://pytorch.org/docs/stable/distributed.html#shutdown (function operator())

# %%
import torch
torch.cuda.empty_cache()

# %% [markdown]
# ## Merging LoRA Weights
# After evaluating the fine-tuned model, you may want to merge the LoRA weights back into the original InternVL2 model. Follow these steps to accomplish this.
#
# Use the provided script to merge the LoRA weights into the base model. The script takes two arguments: the input path of the fine-tuned model and the output path for the merged model.
#
# `python tools/merge_lora.py <input_path> <output_path>`

# %%
merge_lora_content = '''import torch
import sys
sys.path.append("/content/Vintern/internvl_chat")
from internvl.model.internvl_chat import InternVLChatModel
from transformers import AutoTokenizer
import argparse

argparse = argparse.ArgumentParser()
argparse.add_argument("input_path", type=str, help="Path to the input model")
argparse.add_argument("output_path", type=str, help="Path to the output model")
args = argparse.parse_args()

print("Loading model...")
model = InternVLChatModel.from_pretrained(
    args.input_path, low_cpu_mem_usage=True, torch_dtype=torch.bfloat16).eval()
print("Loading tokenizer...")
tokenizer = AutoTokenizer.from_pretrained(args.input_path, trust_remote_code=True)

if model.config.use_backbone_lora:
    model.vision_model.merge_and_unload()
    model.vision_model = model.vision_model.model
    model.config.use_backbone_lora = 0
if model.config.use_llm_lora:
    model.language_model.merge_and_unload()
    model.language_model = model.language_model.model
    model.config.use_llm_lora = 0

print("Saving model...")
model.save_pretrained(args.output_path)
print("Saving tokenizer...")
tokenizer.save_pretrained(args.output_path)
print("Done!")
'''

with open("/content/Vintern/internvl_chat/tools/merge_lora.py", "w") as text_file:
    text_file.write(merge_lora_content)

# %%
### If could not import internvl edit add
### import sys
### sys.path.append("/content/Vintern/internvl_chat")

# %cd /content/Vintern/internvl_chat
# !python tools/merge_lora.py /content/work_dirs/internvl_chat_v2_0/Vintern_1B_v3_5_finetune_lora_viet_receipt_vqa \
                            /content/work_dirs/internvl_chat_v2_0/Vintern_1B_v3_5_finetune_lora_viet_receipt_vqa_merge
# Out:
# /content/Vintern/internvl_chat
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# 2025-06-28 15:16:11.012396: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751123771.259727    4762 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751123771.319014    4762 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Loading model...
# trainable params: 8,798,208 || all params: 638,496,128 || trainable%: 1.3780
# Loading tokenizer...
# Saving model...
# [2025-06-28 15:16:23,173] [INFO] [real_accelerator.py:254:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-06-28 15:16:25,599] [INFO] [logging.py:107:log_dist] [Rank -1] [TorchCheckpointEngine] Initialized with serialization = False
# Saving tokenizer...
# Done!

# %% [markdown]
# ## Wrapping into AutoModel
# After merging the LoRA weights, you can wrap the fine-tuned InternVL2 model into an AutoModel for easier inference or deployment.
#
# First, copy all the Python scripts from the original InternVL2-2B directory to the new merged model directory:

# %%
# !ls /content/work_dirs/internvl_chat_v2_0/Vintern_1B_v3_5_finetune_lora_viet_receipt_vqa_merge
# Out:
# added_tokens.json	merges.txt		 tokenizer_config.json
# config.json		model.safetensors	 tokenizer.json
# generation_config.json	special_tokens_map.json  vocab.json

# %%
# !cp /content/Vintern/pretrained/Vintern-1B-v3_5/*.py \
    /content/work_dirs/internvl_chat_v2_0/Vintern_1B_v3_5_finetune_lora_viet_receipt_vqa_merge

# %% [markdown]
# Next, copy the config.json file from the original InternVL2-1B directory to the new merged model directory:

# %%
# !cp /content/Vintern/pretrained/Vintern-1B-v3_5/config.json \
    /content/work_dirs/internvl_chat_v2_0/Vintern_1B_v3_5_finetune_lora_viet_receipt_vqa_merge

# %% [markdown]
# # Inference with fintuned model

# %% [markdown]
# After copying the necessary files, you can now load and use the fine-tuned InternVL2 model with AutoModel for inference

# %%
import os
import numpy as np
import torch
import torchvision.transforms as T
from PIL import Image
from torchvision.transforms.functional import InterpolationMode
from transformers import AutoModel, AutoTokenizer
import matplotlib.pyplot as plt

IMAGENET_MEAN = (0.485, 0.456, 0.406)
IMAGENET_STD = (0.229, 0.224, 0.225)

def build_transform(input_size):
    MEAN, STD = IMAGENET_MEAN, IMAGENET_STD
    transform = T.Compose([
        T.Lambda(lambda img: img.convert('RGB') if img.mode != 'RGB' else img),
        T.Resize((input_size, input_size), interpolation=InterpolationMode.BICUBIC),
        T.ToTensor(),
        T.Normalize(mean=MEAN, std=STD)
    ])
    return transform

def find_closest_aspect_ratio(aspect_ratio, target_ratios, width, height, image_size):
    best_ratio_diff = float('inf')
    best_ratio = (1, 1)
    area = width * height
    for ratio in target_ratios:
        target_aspect_ratio = ratio[0] / ratio[1]
        ratio_diff = abs(aspect_ratio - target_aspect_ratio)
        if ratio_diff < best_ratio_diff:
            best_ratio_diff = ratio_diff
            best_ratio = ratio
        elif ratio_diff == best_ratio_diff:
            if area > 0.5 * image_size * image_size * ratio[0] * ratio[1]:
                best_ratio = ratio
    return best_ratio

def dynamic_preprocess(image, min_num=1, max_num=12, image_size=448, use_thumbnail=False):
    orig_width, orig_height = image.size
    aspect_ratio = orig_width / orig_height

    # calculate the existing image aspect ratio
    target_ratios = set(
        (i, j) for n in range(min_num, max_num + 1) for i in range(1, n + 1) for j in range(1, n + 1) if
        i * j <= max_num and i * j >= min_num)
    target_ratios = sorted(target_ratios, key=lambda x: x[0] * x[1])

    # find the closest aspect ratio to the target
    target_aspect_ratio = find_closest_aspect_ratio(
        aspect_ratio, target_ratios, orig_width, orig_height, image_size)

    # calculate the target width and height
    target_width = image_size * target_aspect_ratio[0]
    target_height = image_size * target_aspect_ratio[1]
    blocks = target_aspect_ratio[0] * target_aspect_ratio[1]

    # resize the image
    resized_img = image.resize((target_width, target_height))
    processed_images = []
    for i in range(blocks):
        box = (
            (i % (target_width // image_size)) * image_size,
            (i // (target_width // image_size)) * image_size,
            ((i % (target_width // image_size)) + 1) * image_size,
            ((i // (target_width // image_size)) + 1) * image_size
        )
        # split the image
        split_img = resized_img.crop(box)
        processed_images.append(split_img)
    assert len(processed_images) == blocks
    if use_thumbnail and len(processed_images) != 1:
        thumbnail_img = image.resize((image_size, image_size))
        processed_images.append(thumbnail_img)
    return processed_images

def load_image(image_file, input_size=448, max_num=12):
    #check image_file is a path or image
    if isinstance(image_file, str):
        image = Image.open(image_file).convert('RGB')
    else:
        image = image_file
    image = image.resize((input_size, input_size))

    transform = build_transform(input_size=input_size)
    images = dynamic_preprocess(image, image_size=input_size, use_thumbnail=True, max_num=max_num)
    pixel_values = [transform(image) for image in images]
    pixel_values = torch.stack(pixel_values)
    return pixel_values

# %%
## load pretrained model
model_name = "/content/work_dirs/internvl_chat_v2_0/Vintern_1B_v3_5_finetune_lora_viet_receipt_vqa_merge"

model = AutoModel.from_pretrained(model_name,
                                  torch_dtype=torch.bfloat16,
                                  use_flash_attn=False,
                                  low_cpu_mem_usage=True,
                                  trust_remote_code=True).eval().cuda()
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True, use_fast=False)
# Out:
# A new version of the following files was downloaded from https://huggingface.co/5CD-AI/Vintern-1B-v3_5:
# - configuration_intern_vit.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/5CD-AI/Vintern-1B-v3_5:
# - configuration_internvl_chat.py
# - configuration_intern_vit.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/5CD-AI/Vintern-1B-v3_5:
# - conversation.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/5CD-AI/Vintern-1B-v3_5:
# - modeling_intern_vit.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/5CD-AI/Vintern-1B-v3_5:
# - modeling_internvl_chat.py
# - conversation.py
# - modeling_intern_vit.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.

# %%
# !gdown https://drive.google.com/drive/folders/17FFnVEgJjWCgKlHzppYOeXfBRQIV--3D?usp=sharing --folder -O /content/test
# Out:
# Retrieving folder contents
# Processing file 1zZK63yoQUbD6WR1Sbyk_1eM-WqnUkfcL hoa_don_1.jpg
# Processing file 1NAGuAOmFXxEHaKrWDp7Ib51vAeE88u3z hoa_don_2.jpg
# Processing file 11_Zo_odRMy5vun--AxsGcN3DNAM-Xj7l hoa_don_3.jpg
# Processing file 1bh_DbKNQRi-JP2cQLFtFZyUwLlpWuxcu hoa_don_4.jpg
# Processing file 1xGrvsVpTuFL6pgTH-qR9NWodVayuhZOS hoa_don_5.jpg
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1zZK63yoQUbD6WR1Sbyk_1eM-WqnUkfcL
# To: /content/test/hoa_don_1.jpg
# 100% 191k/191k [00:00<00:00, 125MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1NAGuAOmFXxEHaKrWDp7Ib51vAeE88u3z
# To: /content/test/hoa_don_2.jpg
# 100% 143k/143k [00:00<00:00, 132MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=11_Zo_odRMy5vun--AxsGcN3DNAM-Xj7l
# To: /content/test/hoa_don_3.jpg
# 100% 178k/178k [00:00<00:00, 132MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1bh_DbKNQRi-JP2cQLFtFZyUwLlpWuxcu
# To: /content/test/hoa_don_4.jpg
# 100% 290k/290k [00:00<00:00, 92.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1xGrvsVpTuFL6pgTH-qR9NWodVayuhZOS
# To: /content/test/hoa_don_5.jpg
# 100% 170k/170k [00:00<00:00, 89.6MB/s]
# Download completed

# %%
### Test samples
test_folder = '/content/test'
for filename in os.listdir(test_folder):
    image_path = os.path.join(test_folder, filename)
    image = Image.open(image_path).convert('RGB')

    plt.figure(figsize=(5,5))
    plt.imshow(image)
    plt.show()

    pixel_values = load_image(image_path, max_num=12).to(torch.bfloat16).cuda()
    generation_config = dict(max_new_tokens= 1024, do_sample=False, num_beams = 3, repetition_penalty=2.0)

    question = '\nTrích xuất thông tin hoá đơn trong ảnh.'

    response = model.chat(tokenizer, pixel_values, question, generation_config)
    print(f'User: {question}\nAssistant: {response}')
    print("="*30)
# Out:
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# User:
# Trích xuất thông tin hoá đơn trong ảnh.
# Assistant: {'Tên quán': 'QUAN AN THIEN TAN', 'Địa chỉ': '17-19 TON DAN F13Q4 PHCM', 'Số điện thoại': '9407863-629956', 'Ngày giờ': '13-11-2011 20:54', 'Số hóa đơn': '000887', 'Mã sản phẩm': 'BANSO: 47', 'Danh sách món': [{'Tên món': 'Bún Sing', 'Đơn giá': '42.000', 'Số lượng': '1'}, {'Tên món': 'Mì Giòn X Chay', 'Đơn giá': '37.000', 'Số lượng': '1'}, {'Tên món': 'Ngon N', 'Đơn giá': '80.000', 'Số lượng': '1'}, {'Tên món': 'Cơm Bát Bửu', 'Đơn giá': '172.000', 'Số lượng': '1'}, {'Tên món': 'Sườn Chiên KDO', 'Đơn giá': '65.000', 'Số lượng': '1'}, {'Tên món': 'Hủ Tiêu N', 'Đơn giá': '40.000', 'Số lượng': '1'}, {'Tên món': 'Tôm Lăn Bột', 'Đơn giá': '65.000', 'Số lượng': '1'}, {'Tên món': 'Pepsi', 'Đơn giá': '16.000', 'Số lượng': '1'}, {'Tên món': 'Trà Da', 'Đơn giá': '20.000', 'Số lượng': '10'}], 'Tổng tiền': '537.000', 'Tiền mặt': '537.000'}
# ==============================
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# User:
# Trích xuất thông tin hoá đơn trong ảnh.
# Assistant: {'Tên quán': 'Cafe', 'Địa chỉ': '35 Xuân Thủy - Phường Thảo Điền - Quận 2', 'Số điện thoại': '08 66 84 1111 - 0967041111', 'Tên món': ['Cà phê đá', 'Cà phê đen', 'Cà phê sữa đá', 'Cơm đen', 'Cơm sườn'], 'Số lượng': [1, 1, 1, 1, 1], 'Đơn giá': [18.0, 18.0, 13.0, 1.0, 1.0], 'Thành tiền': [18.0, 18.0, 13.0, 150.0, 150.0], 'Tổng cộng': 181000, 'Giảm %': 0, 'VAT': 1900, 'Tiền mặt': 198200, 'Quy đổi USD': 21000, 'Tỷ giá': 9, 'Số tiền khách đưa': 200000, 'Số tiền thôi lại': 18900}
# ==============================
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# User:
# Trích xuất thông tin hoá đơn trong ảnh.
# Assistant: {'Tên quán': 'Coffee Kem Sen Trắng', 'Địa chỉ': 'Đường Số 2 - KDC 135 - TT Bến Lức', 'Số hóa đơn': '0006', 'Ngày': '13/09/2017', 'Giờ': '12:24:54', 'Bàn': 'A', 'Tên món': ['Yaourt Nha Đam', 'Chanh Dây', 'Kem Socola', 'Kem Vanilla', 'Kem Sầu Riêng', 'Kem Dừa', 'Nước Ép Ói', 'Nước Ép Thơm', 'Dứa'], 'Số lượng': [1, 1, 1, 1, 1, 1, 1, 1, 1], 'Đơn giá': [25000, 20000, 22000, 22000, 22000, 22000, 28000, 28000, 28000], 'Thành tiền': [25000, 20000, 22000, 22000, 22000, 22000, 28000, 28000, 28000]}
# ==============================
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# User:
# Trích xuất thông tin hoá đơn trong ảnh.
# Assistant: {'Tên công ty': 'Công ty TNHH Công Nghệ', 'Địa chỉ': '362/13 Đường Đuối Nam, P. Hiệp Thành, Q. 12, Thành phố Đà Nẵng', 'Số điện thoại': '0769087777', 'Ngày': '07/11/2022', 'Số phiếu': '22000007', 'Thu ngân': 'Administrator', 'Khách hàng': 'ANH HOÀNG', 'Mặt hàng': ['Áo dạ cải pk', 'Áo dạ khuy cổ', 'Áo dạ sát nách', 'AO DA HÂN', 'Áo dạ sát nách'], 'SL': ['1', '1', '1', '1', '1'], 'ĐVT': ['cái', 'cái', 'cái', 'cái', 'cái'], 'Giá': ['1,499,000', '1,690,000', '1,210,000', '870,000', '1,210,000'], 'Tính': ['1,499,000', '1,690,000', '1,210,000', '870,000', '1,210,000'], 'Tổng SL': '5', 'Tổng tiền hàng': '6,479,000', 'Tiền hàng': '6,479,000', 'Tổng': '6,479,000', 'Khách đưa': '64', 'Điểm trên hóa đơn': '1,957', 'Tổng tích lũy': '1,957'}
# ==============================
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# User:
# Trích xuất thông tin hoá đơn trong ảnh.
# Assistant: {'Tên cửa hàng': 'FamilyMart', 'Địa chỉ': '213 Nguyễn Văn Cừ, P.4, Q.5', 'Số điện thoại': '028-38376974', 'Số hóa đơn': '0021701410421', 'Ngày tháng': '14/07/2017', 'Giờ': '10:42', 'Mã hoá đơn': '0021701410421', 'Tên sản phẩm 1': 'Bún tươi ngon', 'Số lượng 1': '1', 'Đơn giá 1': '23.000', 'Thành tiền 1': '23.000', 'Tổng số lượng': '2', 'Tổng cộng': '2.000', 'Tổng tiền phải trả': '25.000', 'Tiền khách trả': '50.000', 'Tiền thối lại': '25.000', 'Thông tin khác': 'Hãy mua ngay sản phẩm thuộc chương trình Spider-Man, Homme'}
# ==============================

# %% [markdown]
# This guide provided a step-by-step approach to enhancing the InternVL2 model on Viet-Receipt-VQA using LoRA fine-tuning. By following these instructions, you should be able to achieve improved performance in extraction tasks.  Viet-Receipt-VQA is just one example; you can replace it with other downstream datasets for fine-tuning. Happy fine-tuning!
#
# DON'T WORRY ABOUT IT! WE HERE FOR YOU <3
#
# You could find more Vietnamese datasets here.
#
# Check it more about us: [Fifth Civil Defender - 5CD - AI](https://huggingface.co/5CD-AI)
